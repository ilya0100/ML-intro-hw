# %%
import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv("train.csv")

train_df.head()
# Out:
#    id              url                                              title  \
# 0   0          m.kp.md  Экс-министр экономики Молдовы - главе МИДЭИ, ц...
# 1   1        www.kp.by  Эта песня стала известна многим телезрителям б...
# 2   2    fanserials.tv  Банши 4 сезон 2 серия Бремя красоты смотреть о...
# 3   3  colorbox.spb.ru                              Не Беси Меня Картинки
# 4   4    tula-sport.ru  В Новомосковске сыграют следж-хоккеисты алекси...
#
#    target
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False

# %%
len(train_df)
# Out:
# 135309

# %%
test_df = pd.read_csv("test.csv")

test_df.head()
# Out:
#        id                url  \
# 0  135309  www.kommersant.ru
# 1  135310    urexpert.online
# 2  135311      imperimeha.ru
# 3  135312  national-porn.com
# 4  135313            2gis.ru
#
#                                                title
# 0  Шестой кассационный суд в Самаре начнет работу...
# 1  Что такое индексация алиментов, кем и в каких ...
# 2                  Женщинам | Империя Меха - Part 12
# 3  Небритые, волосатые киски: Порно всех стран и ...
# 4                                                 67

# %%
len(test_df)
# Out:
# 165378

# %%
train_df["target"].value_counts()
# Out:
# False    118594
# True      16715
# Name: target, dtype: int64

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/ilya/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import re
import pymorphy2

from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB, ComplementNB
from sklearn.preprocessing import StandardScaler

# %%
TOKEN_PATTERN = "[а-яё]+"
SEED = 42

# %%
stop_words = nltk.corpus.stopwords.words("russian")

# %%
X_train = train_df["title"].values
X_test = test_df["title"].values
y_train = train_df["target"].astype(int).values

# %%
def tokenize(text):
    return re.findall(TOKEN_PATTERN, text.lower())

X_train_tokenized = [tokenize(text) for text in X_train]

# %%
lemmatizer = pymorphy2.MorphAnalyzer()

lemmatizer_cache = {}

def lemmatize(token):
    if lemmatizer.word_is_known(token):
        if token not in lemmatizer_cache:
            lemmatizer_cache[token] = lemmatizer.parse(token)[0].normal_form
        return lemmatizer_cache[token]
    return token

# %%
X_train_lemmatized = [[lemmatize(token) for token in text] for text in X_train_tokenized]

X_train_cleared = [" ".join([token for token in text if token not in stop_words]) for text in X_train_lemmatized]

# %%
X_train
# Out:
# array(['Экс-министр экономики Молдовы - главе МИДЭИ, цель которого сделать из республики не просителя, а донора: Надо избегать долгого нахождения н�',
#        'Эта песня стала известна многим телезрителям благодаря сериалу Диверсант-2',
#        'Банши 4 сезон 2 серия Бремя красоты смотреть онлайн!', ...,
#        '1941 Plymouth Special Deluxe Hot Rod, Automatic,Small Block,Power Steering, A/C for sale: photos, technical specifications, description',
#        "Купить It's Skin Сыворотка питательная Power 10 Formula YE Effector, 30 мл в Москве - WOWCREAM",
#        'Технический спирт в канистрах и флаконах, купить в Москве'],
#       dtype=object)

# %%
X_train_cleared
# Out:
# ['экс министр экономика молдова глава мидэи цель который сделать республика проситель донор избегать долгий нахождение н',
#  'песня стать известный многий телезритель благодаря сериал диверсант',
#  'банши сезон серия бремя красота смотреть онлайн',
#  'бесить картинка',
#  'новомосковск сыграть следж хоккеист алексинский звезда сборная китай',
#  'салат корейский морковь копчёный курица кукуруза сухарик калорийность белка жир углевод',
#  'угловой пневмогайковерт екатеринбург купить цена отзыв характеристика фото инструкция',
#  'табачный магазин мир табак курительный трубка курительный труба',
#  '',
#  'р одесса ростов дон сентябрь фаворит чп',
#  'огэ математик функция задача ответ готовый',
#  'мировой экономика схема таблица млн результат поиск',
#  'кримпай мать сын страница смотреть порно мультик порно комикс хентай онлайн бесплатно',
#  'мария шорох право выбор академия си читать онлайн',
#  'днепр наслать пропасть летний девушка',
#  'мир',
#  'слава медяник стучать колесо',
#  'инженерный институт казанский приволжский федеральный университет учёба ру',
#  'каков основной черта размещение отрасль топливный промышленность территория россия млн результат поиск',
#  'мужик поставить блондинка рак отодрать тугой очко порно видео',
#  'портер джейн звёздный дождь скачать бесплатно книга формат',
#  'порно который искать видео',
#  'услуга городской номер подключить мобильный билайн ульяновск',
#  '',
#  'погода сочи сентябрь тыс результат поиск',
#  'погода гостомел дн прогноз погодить дн рп нь ки вська область укра',
#  'служба поддержка',
#  'учётный запись нальчик',
#  'кожа волос ноготь результат поиск',
#  'форма наряд допуск производство работа место действие опасный вредный фактор снип безопасность труд строительство часть первый',
#  'ласточка аккорд текст видео',
#  'школьный форма солнце мода чёрный цвет цена руб купить гомель',
#  'диалог',
#  'купить встраив газовый панель каталог интернет магазин м видео выгодный цена доставка отзыв фотография вести',
#  '',
#  'форма леденец шоколад курочка ряба купить',
#  'погода ноябрь новость казахстан',
#  'видео видео',
#  '',
#  '',
#  'отзыв домкрат подкатной гидравлический онт удобный тяжёлый домкрат',
#  'лесбийский секс кунилингусом стройный студентка высококачественный порно видео участие эмиль блум',
#  'презентация тема приблизить значение абсолютный относительный погрешнос',
#  'горбачёв октябрь намеренный участвовать заседание иск жириновский политика тасс',
#  'москва марокко ночь руб',
#  'гоша матарадзе сердце слушать бесплатно онлайн',
#  'миска салатник страница',
#  '',
#  'мельница крупорушка заводский изготовление квт срочно грн оборудование кременчуг',
#  '',
#  'изюминка лимончик обычный',
#  'снять быстросъем печка фокус тыс результат поиск',
#  '',
#  '',
#  'маленький характер частный детский сад детский центр хорошево мнёвники',
#  '',
#  'фото голый девочка бесплатный эротика',
#  'порно видео эротический фильм малолетка',
#  'свет свет оренбург оренбургский обл россия год мир',
#  'вакансия микролаб системс москва работа микролаб системс',
#  'ассасинавт скачать торрент хороший качество',
#  'ведущий специалист закупка',
#  'дима билан сняться фильм андрей кончаловского',
#  'русский наследница сезон смотреть онлайн хороший качество',
#  'купить беговой дорожка квартира интернет магазин зона спорт интернет м',
#  'профессия стыковщик текстиль пресса описание зарплата',
#  'фото пейзаж пейзажный фотография страница социальный сеть фотокто',
#  'бишунму танцующий небо серия сезон смотреть онлайн',
#  'характеристика различный вид перевозка груз буква ру научно популярный портал',
#  'кольцо инкрустация цирконий р р р позолота продажа цена ровно кольцо перстень оптовый интернет магазин позолотить бижутерия',
#  'судак затонуть прогулочный катер турист пассажирка погибнуть яплакалъ',
#  'общий положение консультантплюс',
#  'фильм смешной девчонка смотреть онлайн полностью качество бесплатно',
#  'начало смотреть онлайн бесплатно хороший качество',
#  'фильм артек фото видео список актёр вокруг тв',
#  'разбирать принтер замятие бумага аналогичный принтер смотреть видео онлайн',
#  'воровайки мурки воровайки клип смотреть онлайн',
#  'восход заход солнце астана тыс результат поиск',
#  'блокування мост метро кличко розпов що м нувальник мав серйозн ри перебував стан сп ян ння новини ки ва ки',
#  'книга магия поцелуй морить триша литлайф книга читать онлайн скачать бесплатно полный книга',
#  'читать манга крутой учитель онидзука глава русский онлайн',
#  'читать манга друг мир имя чёрный целитель глава русский онлайн',
#  'кр улуттук банкынын нарын облустук башкармалыгынын филиалынын улук бухгалтери токтакунова кызматынан негизсиз четтетилген кабар кыргыз улуттук маалымат агенттиги',
#  '',
#  'изумрудный сказка эсми никс ямогу каталог мастер автор кукла игрушка кукольный одежда аксессуар бэйбики кукла фото одежда кук',
#  'рисовый каша вода рецепт фото',
#  'горный болезнь',
#  'супервайзер книга супервайзер увеличить объём продажа',
#  '',
#  'натуральный волос',
#  'назвать человек думать большой',
#  'фильтр страница',
#  'пол пола пол закупка этап подача заявка пермь пермский край пермский р н',
#  'м ф ромео обочина индия',
#  'росфинмониторинг почта',
#  'порошенко п дписав антирейдерський земельний закон укра нська правда',
#  'морковный палочка',
#  'государственный музей л н толстой гмт элкос дизайн',
#  'рамблер касса',
#  'шикарный молодой женщина обнажённый соска эротика фото голый целоваться девушка раздетый женщина',
#  'фото фото фотография олеся швецов',
#  'строительство коттедж пенобетон ключ омскдом',
#  'военный тематика страница скачать книга формат бесплатн',
#  'магазин электронный компонент электронщик продажа электронный компонент радиодеталь измерительный техника светотехнический',
#  'сушка дерево вакуумный камера',
#  'срок поставка киа пиканто субкомпактный автомобиль',
#  'почтовый индекс улица лев толстой санкт петербург номер дом',
#  'комплект муравьиный ферма горный мох купить белгород интернет магазин',
#  '',
#  'презентац сутн сть маркетинг його визначення',
#  'марсель муратов казань татарстан россия год мир',
#  '',
#  'администрация дк',
#  'город холм',
#  'челябинский область появиться ещё виртуальный концертный зал',
#  'анжелика агурбаш любовь твой мало музыка скачать бесплатно слушать музыка анжелика агурбаш любовь твой мало песня песня онлайн',
#  'необычный рецепт вкусный идея каждый день',
#  'девчата радость пописать туалет сообщение москва',
#  'гостиница авс отель россия свердловский область екатеринбург цена',
#  'купить кронштейн тв наклонно поворотный каталог интернет магазин м видео выгодный цена доставка отзыв фотогра',
#  '',
#  'технический функциональный возможность интерактивный доска тема научный статья общий комплексный проблема естественный точн',
#  'секс знакомство обмен интим фото регистрация бесплатно смс',
#  'смотреть онлайн',
#  'подсказать ваш ребёнок написать централизовать работа геометрия который наш класс поход очень',
#  '',
#  'азаров английский язык младший школа скачать беслатно учебник тетрадь аудио карточка весь класс',
#  'ребёнок красный глаз гноиться ребёнок красный глаз гной',
#  'урал играть кёрлинг автомобиль око смотреть видео онлайн мир олег фролов',
#  'читать книга оригинал си страница библиотека книга',
#  'игра скачать торрент бесплатно регистрация',
#  'бархатцы махровый гигант гр цп семя алтай',
#  'смотреть видео онлайн мир',
#  'собака поезд укрзализныця объяснить правило перевозка животное сегодня',
#  'фильм жанр комедия смотреть онлайн бесплатно',
#  'реклама',
#  'ленинский район сентябрь состояться очередной заседание комиссия профилактика правонарушение',
#  'побег лос анджелес слушать скачать',
#  'таинственный лес тайна покрыть мрак отзыв',
#  'танцевальный клуб импульс белгород ребёнок год',
#  'скачать клуб винкс сезон серия обратно средний век русский никелодеон смотреть онлайн',
#  'мир',
#  'против язва',
#  'большой шар кукла купить краснодар цена руб дата размещение игрушка игра',
#  'интернет магазин женский мужской детский одежда обувь аксессуар онлайн доставка день бесплатный отправка заказ',
#  'соликамск база данные недвижимость соликамск сайт объявление продажа аренда объявление',
#  '',
#  'водитель элитный мерседес убийца который насмерть сбить парень бауманский экстрадировали мюнхен москва',
#  'тайный война воздушный штрафбата война художественный литература читать онлайн',
#  'отправление ответ объявление огосекс ру',
#  'результат поиск запрос секрет пластилин интернет магазин читать город',
#  'читать манга скала кен глава русский онлайн',
#  'крыло правый передний автозапчасть горный алтайск',
#  'акция пятёрочка завтрак каша машина ваш',
#  'колледж красноярск специальность преподавание начальный класс',
#  'натали инстаграм фотография',
#  'кожаный сумка купить интернет магазин домани',
#  'фильтр поиск',
#  'купить кабель пульт микрофон цена руб',
#  'читать',
#  'порно видео скачать смотреть фильм',
#  '',
#  'постоянно гореть ответ ремонт эксплуатация форум авто',
#  'передний энциклопедия',
#  'песня номад сезон выпуск фрагмент песня смотреть онлайн видео бесплатно видеохостинг',
#  'взрыв завод поставщик тойота сказаться производство компания россия',
#  'хороший цена деталь хороший цена поставщик деталь',
#  '',
#  'оператор получение входной данные пользователь процедура',
#  'студент який кинуть яйцо янукович роц дора директор департамент ода портал новина',
#  'бережинський ззсо ступен ровоградська область суо',
#  'луг фреш синюга',
#  'скачать андроид отзыв промокод деньга телефон рф',
#  'специальность сибгу м ф решетнёв направление образование бакалавриат языкознание литературоведение красноярск',
#  'атлантис тв кабельный телевидение гай адрес описание отзыв',
#  'гдз номер математик класс рабочий тетрадь г мерзляк б полонский',
#  'результат поиск запрос гарри потереть',
#  'девочка самый интересный фото дом солнце',
#  'портфель',
#  'й й',
#  '',
#  '',
#  'смотреть видео онлайн бесплатно',
#  '',
#  'общественный политический организация пенза ул титов организация',
#  'горячий закуска банкетный зал шартрез',
#  'офис сезон серия смотреть онлайн высокий качество',
#  'танк армата поступить армия экспресс газета',
#  'сырный дом всё домашний сыроделие',
#  '',
#  'читать книга спать красавица лп страница библиотека книга',
#  'ролевый игра жёстко ебёт далее жена',
#  'отзыв работа сеть кафе столовый подсолнух город новосибирск чёрный сп',
#  'девичий стройность почему француженка толстеть',
#  'сопр вариант дз часть студизба',
#  'класс тест доказательство эволюция',
#  'утверждение перечень государственный работа выполнять государственный учреждение владимирский область отношение который государственный инспекция охрана использование животное мир администрация область осуществлять функция полномочие',
#  'задание решение русский язык класс ладыженская',
#  'эбби глайнс читать книга онлайн бесплатно',
#  'услуга трубочист спб прочистка дымоход вентканалов',
#  'слив обучение форум социальный инженерия',
#  'поездка попутчик дать водитель',
#  'газэнергоавтоматика',
#  'идея создание новогодний уют дом',
#  'великий северный война программа виват история виват история подкаст',
#  'м цветаев никто отнять текст произведение',
#  '',
#  'порно русский секс домашний гей видео видео',
#  'закупка моуо отдел образование администрация куртамышский район',
#  'корова цвет обсуждение российский сервис онлайн дневник',
#  'погода тужаре прогноз погода тужар черниговский область козелецком район неделя украина',
#  'альбом это екатерина год россия екатеринбург сеть знакомство мамба',
#  'ремкомплект суппорт шкода октавия комплект направлять гильза купить киев цена киев автозапчасть абсолют авто абсолютный качество',
#  'зозуля дитяч п сн укра нськ дитяч п сн',
#  'результат поиск запрос железный хватка',
#  'скачать порно телефон дама цепь трахнуть ебальной машина свой друг',
#  'капернаум фильм онлайн бесплатно кинохолд',
#  'туника г душанбе блузка бесплатный объявление купить продать б',
#  'необходимый проверка безопасность',
#  'фотография бр фото мир',
#  'готовый перевод стать суперзвезда глава',
#  '',
#  'куртка утеплить купить руб интернет магазин',
#  'овертайм новый подвиг летний скол сборный испания аргентина выйти финал км баскетбол рт русский',
#  'училка стрингах молодой порно фото',
#  'технология производство жби кольцо бетон центр',
#  'артрозилен гель г заказать онлайн купить близкий аптека выгодный цена',
#  'секс бесплатно бесплатный секс видео онлайн каждый день',
#  'скачать онлайн игра обзор официальный сайт видео',
#  'плакат кипелов дар москва дарудар',
#  'файтеры',
#  'дом интерьер красивый дом квартира весь мир пуфик блог дизайн интерьер',
#  'тыс результат поиск',
#  'фотография юлиан тугалова фото мир',
#  'гранитный мойка кухня цвет песочный сантехника водоснабжение',
#  'защита обратный тяга мм около санкт петербург купить низкий цена отзыв характеристика фото инструкция',
#  'абориген отодрать шикарный девица половой оральный анальный щель отборный порно ебухе',
#  'скачать бесплатно электронный библиотека поиск книга',
#  'читать манга месть масамуне кун глава русский онлайн',
#  '',
#  'немного обычай нрав рай название доминикана страна мама',
#  'сергей жорин александр толмацкий собираться забирать ребёнок вдова децла',
#  'соединение труба корсис труба система установка колодец',
#  'взять заказ',
#  'ежедневно кыргызстанец умирать болезнь сердце эксперт',
#  '',
#  'де ла круз мелисса маскарад страница читать онлайн',
#  'поиск скраб тело',
#  'розбираю грн транспорт запчасть рава русский',
#  'прокат квадроцикл бизнес начать сколько заработать',
#  '',
#  'гдз английский язык класс баранов м страница',
#  'мода',
#  'кыргызча жан ырлар скачать бесплатно текст',
#  'нумерология',
#  'вредность вредничество непокорность язвительство новый естественный лечение',
#  'свадебный вечерний платье новочеркасск салон скарлетт новочеркасск',
#  '',
#  'светодинамический фонтан средний нижний царицынский пруд бирюлёво восточный',
#  'кент кил психопат достоверный рассказ человек жалость совесть раскаяние читать онлайн полностью литрес',
#  'маруся человек бояться показать нужный отпустить пусть бояться далёкий',
#  'свитер мэйбл звезда вязание страна мама',
#  'снеговик',
#  'птуп мартин бел предлагать груз перевозка беларусь',
#  '',
#  'бассейн каркасный прямоугольный смотреть цена грн купить киев',
#  'скомпилировать скрипт каталог файл айта',
#  'женатый парень отжарить молодой соседка втихаря свой жена',
#  'экологический пирамида биомасса численность',
#  'скачать файл',
#  'вакансия работа нормировщик участок тверь поиск работа городработ ру',
#  '',
#  '',
#  'повышенный выделение слизь женщина вид прозрачный выделение заболевание',
#  'танк всё фильм отзыв рецензия смотреть видео онлайн',
#  'автобусный тур бельгия минск цена',
#  'курица кабачок китайски рецепт пошаговый фотография',
#  'хореография ребёнок направление центр знаток',
#  '',
#  'разрушитель легенда сша сериал вебург',
#  'мамка белый нижний бельё удовлетворять бородатый парень спальня',
#  'нож бабочка принтер',
#  'автоматический установка пожарный сигнализация',
#  'николай запорожье год фото страница',
#  'большой козловский переулок далее карта москва',
#  'немолодой женщина показать волосатый вагин порно секс фото зрелый дамочка',
#  'русский порно смотреть российский порнуха бесплатно онлайн страница',
#  'порно видео каролина свитс',
#  'рассрочка трансплантация волос',
#  'й',
#  'наташа мищенко свадебный фотограф ставрополь россия',
#  'россия ужесточить контроль перевод карта карта',
#  'читать манга опасный любовь глава русский онлайн',
#  'людмила баснак алма ата казахстан мир',
#  '',
#  'кран кулер укра н пора вняти ц придбати споживч товари маркетплейс',
#  'альбом развитие речь запись пользователь василиса сообщество детский книга категория самый маленький',
#  'макс барский заняться любовь слушать бесплатно онлайн',
#  'мочь бегать одышка рассказывать',
#  'просклонять слово кроватка падеж безбукв ру',
#  'фотография анастасия соломонов фото мир',
#  'анданте сезон торрент сериал скачать бесплатно смотреть онлайн',
#  'технология покраска бетон',
#  'ставка рефинансирование ключевой ставка цб рф год таблица',
#  'читать манга восьмой сын мочь это принять глава русский онлайн',
#  '',
#  'фильм операция тушёнка смотреть онлайн бесплатно хороший качество',
#  'купить туалетный кабина х х м невинномысск невинномысск производитель',
#  'купить тонометр механический иад стетоскоп комплект аптека московский регион доставка сравнение цена аптекамос',
#  '',
#  'обои природа обои рабочий стол фото',
#  'трансформатор грн прочий электроника запорожье',
#  'худи спортивный худи капюшон больший наклданым карман кенгуру ткань одежда женщина',
#  'дорама цветочек ягодка смотреть онлайн русский озвучка результат поиск',
#  'скачать бесплатно песня',
#  'рожанец александр робертович физиотерапевт отзыв запись приём',
#  '',
#  'фото топ р новый цена р',
#  'разный магний стр запись пользователь марина сообщество благополучный беременность категория медикамент витамин процедура',
#  'черёмуховый сайт город североуральск',
#  'презентация тема построение курс математика умк перспективный начальный широта',
#  'сдаваться двухкомнатный квартира кв м екатеринбург вторчермет эскадронный ул руб месяц',
#  'вакансия работа дворник разнорабочий прямой работодатель москва поиск работа городработ ру',
#  'скачать песня бесплатно слушать онлайн',
#  'дроссельный заслонка газель купить барнаул цена новый бу контрактный запчасть авто газ газель',
#  'заготовка рецепт',
#  'отзыв покупатель',
#  'наталья москва',
#  'администратор',
#  'хороший светодиодный лента год топ рейтинг хороший',
#  'обои видео игра обои рабочий стол фотография видео игра',
#  'значение имя иннокентий кеш',
#  'работа поиск работа минск беларусь',
#  'гдз русский язык класс решебники ответ онлайн',
#  'комплексный центр социальный обслуживание население бологовский район структура центр',
#  'документ учёба',
#  'подсветка салон передний плафон цена руб купить санкт петербург',
#  '',
#  'профессор карапуз музична пригода бесплатно скачать',
#  'продать г пмр авторынок пмр молдова клаксон',
#  'визит осенний визит спектр кредо электронный библиотека асмодея',
#  'вакансия слесарить механосборочный работа тула работа витра',
#  'рукоделие картина образ рукодельница живопись картина современный художник',
#  'смешной картинка прикол комикс гиф анимация видео хороший интеллектуальный юмор',
#  '',
#  'нахальный пронырливый человек буква',
#  '',
#  '',
#  'тур отель турция аланья цена отзыв',
#  'объявление снять комнатный квартира район центральный город хабаровск аренда трехкомнатных квартира длительный срок найти',
#  'стоматология улыбка всевластие стоматолог улыбка зуб властел',
#  'перечень предохранитель компонетов блок реле предохранитель расположить панель управление руководство обслуживание ремонт',
#  '',
#  '',
#  'отзыв моделирующий паста тело похудение экспресс греческий талассо',
#  'дестабилизировать это дестабилизировать',
#  'стр работа нур султан объявление вакансия',
#  'мир',
#  'горло отоларингология здоровье',
#  'фото город бетлица россия фотография',
#  'версия',
#  'читать книга поцелуй горец автор монинг карен онлайн страница читать книга регистрация',
#  'спасибо покупка',
#  'надежда псков',
#  'оргия яхта море порно видео онлайн смотреть бесплатно',
#  'проверка отзыв сайт',
#  'аладдин мультфильм смотреть онлайн хороший качество бесплатно',
#  '',
#  '',
#  'преддипломный практика начальный школа',
#  'сковорода сотейник купить крым севастополь симферополь керчь феодосия ялта страница',
#  '',
#  '',
#  'конструктор строительный площадка купить тольятти цена руб дата размещение игрушка игра',
#  'хороший цена трос стояночный тормоз хороший цена поставщик трос стояночный тормоз',
#  'некоторый думать футбол это дело жизнь смерть совершенно разочаровать позиция футбол намного важный свободный мнение бло',
#  'скачать торрент',
#  '',
#  '',
#  'знакомство парень краснодарский край новороссийск результат поиск сайт знакомство тралоло',
#  'сказка поп работник балда пушкин читать онлайн',
#  '',
#  'ылым саласында ы сыйлы тара мена мемлекетт ылыми стипендиялар туралы аз стан республикасы мета н жыл ы широта лдедег аулысы',
#  'сонник новый отношение присниться сниться новый отношение сон видеть',
#  'куркума вага тност експерти назвать неспод ван користь але нюанси',
#  '',
#  'фото альбом фото группа фото фотография тренд',
#  'кондиционер волос заказать германия доставка',
#  'харампурнефтегаз получить право строительство объект харампурском месторождение',
#  'остров миагани последний бомба местонахождение',
#  'архитектурный вуз университет институт академия факультет саратовский область вуз архитектор учёба ру',
#  'авторизац портал',
#  '',
#  'спортмастер г санкт петербург трк жемчужный плаз петергофское шоссе далее г санкт петербург',
#  'урок музыка главный кит песня класс урок',
#  'извадете електричеството както сте избрать електрически длето универсальный инструмент работилница домашен фурнир',
#  'александра загран паспорт помочь',
#  'почта',
#  'синоним слово удержать вертикальный положение',
#  'читать манга макрофаг ломать канон глава русский онлайн',
#  '',
#  'начальный уровень гдз решебник физика класс',
#  'работа сфера транспорт автобизнес автосервис руб москва',
#  '',
#  'социальный сеть позволять знакомиться общятся человек отправлять смс ещё',
#  'фильм закон каменный джунгли фильм фото видео список актёр вокруг тв',
#  'бедный настя серия смотреть онлайн сериал красвью',
#  'обувь страница',
#  'мотоциклист погибнуть столкновение иномарка улица землячка сормовский район нижний новгород сентябрь год новость',
#  'плохой отзыв прочитать',
#  'приказ минобразования рф',
#  'электротриммер',
#  'страница любимый нежность читать онлайн юлия шкутова полно книга',
#  'схемка осенний красота лист мариэлла обсуждение',
#  'особенность межнациональный сношение хороший качество вид',
#  'фильм подвиг сила дух рамблер кино',
#  'аренда клад м сигнальный проезд москва свао р н отрадный м владыкино база циан объявление',
#  'погода актаныш сентябрь самый очный прогноз сентябрь гидрометцентр актаныш',
#  'разнообразие стиль творчество художник казимир малевич',
#  'блендер купить блендер бош цена отзыв интернет магазин ситилинк таганрог',
#  'мир',
#  'порно телеканал смотреть онлайн бесплатно',
#  'брать скидка всё промокод ваш промокод купон скидка',
#  'мужик развести чужой жена больший сиська',
#  'скачать тас икс фильм сериал игра клип музыка програм',
#  'слушать аудиои книга выжать бизнес всё млн результат поиск',
#  'миля трейлер русский',
#  'фистинг девушка латекс',
#  'китайский биокомпания создать свой первый клонировать котёнок техкульт',
#  'наглядный биохимия кольман г рем год библиотека медицинский л',
#  '',
#  'размер колесо размер колесо',
#  'читать онлайн бартш карина бирюзовый зима электронный библиотека',
#  'алалия методика работа безречевыми ребёнок',
#  'приговор суд ч ст ук рф судебный практика',
#  'масло загар солярий',
#  'серия аниме покорение горизонт озвучка смотреть онлайн',
#  'арсенал частный охранный предприятие челябинск комсомольский проспект дом',
#  'нога пизда видео',
#  'скачать бесплатно слушать онлайн',
#  'ой хто хто миколай любить скачать бесплатно песня качество слушать онлайн',
#  'короткий поздравление дочь день рождение',
#  'м',
#  '',
#  'аквариумистика ру книга аквариумистике секрет аквариумный рыбоводство',
#  'продажа трехкомнатной квартира м ул энтузиаст сургут хант мансийский ао база циан объявление',
#  'оказываться иисус христос выглядеть дело',
#  'точка лежать каждый различный плоскость доказать точка лежать прямой',
#  'отбойный молоток минск продавец магазин интернет магазин',
#  'доверенность отгрузка товар',
#  'дипломный работа взаимодействие семья школа процесс физический воспитание младший школьник скачать бесплатно регистрация',
#  'алюминий моторный закуп переработка цветной чёрный металл',
#  'видео радоловка альбом видео разный разный видео',
#  '',
#  'б',
#  '',
#  'откуда браться плохой отец',
#  '',
#  'склеить пвх плёнка домашний условие простой способ склеивание полиэтиленовый плёнка нужно помнить химия физика',
#  'юля россия южа сайт знакомство',
#  'мерный моргенштерн скачать бесплатно музыка мерный моргенштерн песня песня онлайн',
#  'оплата заказ заказ',
#  'мир',
#  'торрент порно скачать скачать ролик развратный красотуля',
#  'определение июль г дело судакт ру',
#  'канал смотреть онлайн прямой эфир',
#  'инвестиция заработок',
#  'вакансия директор развитие москва работа смартплеер',
#  'двухлетний девочка умереть больница белгородский область постановка капел',
#  'алюминиевый трехсекционная лестница сибртех х ступень пермь купить цена отзыв характеристика фото инструкция',
#  'столото квитанция',
#  'работа сфера складской хозяйство ростов дон',
#  'монте кристо ангел виться ангел суетиться бес цвести сирень слово песня',
#  'война квадрат видео взять самолёт игра битва квадрат смотреть онлайн видео бесплатно видеохостинг',
#  'насколько точно определять расстояние',
#  'фотосессия муж',
#  'интерферон альфа цена наличие аптека купить интерферон альфа украина',
#  'концертный зал колизей санкт петербург афиша мероприятие цена билет',
#  'журавлёв вера анатолиевич репетитор ярославль',
#  'сексапильный тёлочка пососать дать вставить ухажёр',
#  'скачать песня бесплатно',
#  'монолитный поликарбонат ярославль компания полимакс ярославль',
#  'карта сайт',
#  'альбом это александр год россия зеленоград сеть знакомство мамба',
#  'лифтинг клиника идеал специальный цена хороший специалист москва',
#  'город подошва тыс результат поиск',
#  'маленький сиська страница',
#  'й',
#  'хлебопечка цена грн купить сокаль',
#  'юрченко болгария менее нормальный результат футбол владлен юрч',
#  'структура слово основа слово английский любовь',
#  'поезд маршрут ерментау астана',
#  'сериал дорога пустота сезон серия смотреть онлайн бесплатно хороший',
#  'аксиома биржевой спекулянт аудиокнига слушать онлайн',
#  'сумма разность число киберфорум',
#  'гараж час идея малое бизнес',
#  'профиль пользователь рейтинг отель гостиница мир',
#  'изготовление сувенир сувенирный продукция логотип заказ',
#  '',
#  'видео',
#  'лесоустройство учебный пособие',
#  'вч транзистор полевой транзистор полупроводник импортный эль',
#  'индивидуальный предприниматель приймак борис александрович ип реквизит компания октябрьский башкортостан республика россия узн',
#  '',
#  'восстановить пароль контакт номер телефон почта восстановить страница вк иметь доступ телефон знать п',
#  '',
#  'детский сад теремок антитеррористический безопасность',
#  'весёлый ребята октябрёнок текст поиск',
#  'школьный коллекция',
#  'книга оливия гейтс бесплатно скачать читать онлайн регистрация всё',
#  'сколько год алла пугачёв найти поиск',
#  'отзыв инструмент машина заточка сверло нож диолд мзс мнение покупатель интернет магазин диолд',
#  'системный требование отзыв оценка цена скидка гайда прохождение похожий игра',
#  'музыкальный открытка день рождение',
#  'картофель варить жареный деревенски рецепт фото',
#  'доска сосна влажность сухой купить нижний новгород выгодный цена',
#  'новый коррекция запись пользователь мария сообщество ребено',
#  'холодильник тыс результат поиск',
#  'актогай аягоз расписание поезд ктж год',
#  'принцип предпринимательство интернет бизнес экономика',
#  'надземный пешеходный переход глобус леруа мерлен дорога транспорт информационно развлекательный портал',
#  '',
#  'запчасть грузовой легковой автомобиль оборудование сто',
#  'поиск товар запрос контроллер ключ',
#  '',
#  'фбу оренбургский цсм оренбург инна огрн официаль',
#  'мандарин шоколад пошаговый рецепт фото вкусно приготовить',
#  'кроссовок кожаный молния бахрома чёрный',
#  'чёрный кошка ростов дон ростовский обл россия мир',
#  'рахымжан жакайым попурри тойский',
#  '',
#  'секс порно ролик волосатый киска ххх видео онлайн',
#  '',
#  'готовый курсовой работа тема разработка интернет система заказ доставка пицца купить цена руб',
#  'нож финский кованый ст хв литьё рукоять ценный порода дерево',
#  'шапкин павел александрович ип г москва инна реквизит юридический адрес кпп огрн схема проезд сайт телефон узнать',
#  'г',
#  'просмотр увеличить изображение загрузить фото',
#  'игра записка фантастический лес играть онлайн бесплатно',
#  'почтовый индекс улица олег кошевой г владикавказ республика северный осетия',
#  '',
#  'управлять компания жилищный коммунальный сервис чапаевск адрес телефон',
#  'анкета пользователь светлана логинов год лянтор',
#  'результат поиск',
#  'книга логопедический занятие детский сад второй младший группа жанр ме',
#  'шасси прошивка',
#  'глава право користування чужой земельный далее лянкою льськогосподарських потреба цив льний кодекс укра',
#  'читать книга спасатель автор конторович александр онлайн страница сайт',
#  'зелёный оттенок',
#  'работа поиск работа минск беларусь',
#  'сирек казахско русский словарь',
#  'лариса год россия москва фото познакомиться парень проведение совместный досуг трулоло знакомство',
#  'теплоход александр свирский',
#  'поиск дубликат сигарета оптом',
#  'вика год рыба белый анкета знакомство сайт',
#  'время приключение сообщество фанат картинка гифки прикольный комикс интересный статья тема',
#  'карта юбилейный год подробный район название улица номер дом',
#  'бахтеев однофамилец',
#  'порно вк видео',
#  'уплотнитель капот',
#  'магазин правильный мысль',
#  'прилететь ссср год получить секретный беспилотник сша оружие россия информационный агентство',
#  'результат поиск',
#  'гитлер сталин брат близници правда демократический враки верить',
#  'администрация кго почта',
#  'инженер электрик',
#  'ральф смотреть онлайн киного качество бесплатно',
#  '',
#  '',
#  'выездной семинар ицхак адизеса ноябрь баку азербайджан',
#  'страница услуга уральск объявление оказание платный услуга',
#  'подключаться громкий связь видеовызове поиск',
#  'ракетка бадминтон купить ракетка бадминтон самара низкий цена экипировочный центр',
#  'ташкентский область ташкент результат поиск сайт знакомство',
#  'бум весна осень зима страница',
#  'запчасть грузовой легковой автомобиль оборудование сто',
#  'ошибка фнс россия',
#  'налоговый кодекс рк статья исчисление амортизационный отчисление',
#  'танец минус весна текст песня слово',
#  'кассета велосипед звезда аксессуар запчасть велосипед',
#  '',
#  'иос отопление вентиляция кондиционирование воздух тепловой сеть облако',
#  'костюм термо век пума',
#  'поиск человек снежана варычева',
#  'поездка попутчик дать водитель',
#  'этажный дом м аренда длительный срок ярославль промзона улица декабрист объявление',
#  'почему неуверенность являться главный причина мешать найти любовь женский журнал всё мода шоу бизнес отношение кр',
#  'скачать песня бесплатно музыкальный подборка альбом исполнитель слушать музыка онлайн заяц',
#  '',
#  'красивый русский секс камшотом ягодица девушка',
#  'порно латинки страница',
#  'светлана кинберг',
#  'вспомнить весь поимённо',
#  'скачать смотреть онлайн',
#  'хатиора название описание фото вид растение гермин солеросовая отличие кактус рипсалиса также ядовитый комн',
#  'объединение кондитер отзыв млн результат поиск',
#  'водопад чистка защита автор',
#  'читать манга красный кровь красный наследие глава русский онлайн',
#  'гомельский область мошенник выманить предприниматель товар тыс рубль',
#  'валерий википедия тыс результат поиск',
#  'список литература болезнь почка',
#  'далее билет октябрь москва липецк выбор поезд',
#  'сбежать баку скачать клип бесплатно смотреть онлайн',
#  'тройчатый харьков расписание электричка пригородный поезд',
#  'толстовка женщина россия',
#  'идти загрузка',
#  'авиабилет казань астрахань рубль',
#  'единый дежурный диспетчерская служба тольятти хороший страна волжский коммуна',
#  'песня караоке жанр несчастный любовь бесплатный караоке караопа ру',
#  'мокап рисунок',
#  'игра драгоценный камень взрыв играть онлайн бесплатно',
#  'новый плащ подкладе купить санкт петербург цена руб продать июль верхний одежда',
#  'видео ктз русый видео',
#  'автомобиль запчасть новосибирск',
#  'тело телефон приволжский электрический сеть оп ао саратовэнерго поволжье номер',
#  'ракушка барахолка',
#  'электронный регистратура самарский область купаева н б',
#  'тюлька треск тыс результат поиск',
#  'купить шоколадный пончик г кредит кокшетау магазин',
#  'подтвердить дизайн',
#  'елена',
#  'вчера великий новгород обсудить достижение слабый место молодёжный политика',
#  '',
#  'фильм сквозь туман скачать торрент хороший качество бесплатно',
#  'русский скачать торрент игра бесплатно регистрация',
#  'бытсервис оао апатит ул октябрьский далее',
#  'шагать москва который большой иван ургант пронзительно попрощаться георгий данелия рамблер новость',
#  '',
#  'фотография депрессия',
#  'импорт компьютерный комплектующие',
#  'пять золотой пять делиться делиться попробовать разделить пять получаться получать цитата афоризм',
#  'стол заказ страница',
#  'телефон газовый служба тобольск',
#  'запечь шампиньон сыр сметана',
#  '',
#  'адрес организация санкт петербург подать жалоба коммунальный служба',
#  'пг п нв переключатель галетный интернет магазин',
#  'дверной полотно глухой каролина х мм красный дерево радиал цена',
#  'личный кабинет',
#  'мода деньга бесконечный ресурс игра скачать бесплатно крутой ролевый файтинг',
#  'мерседес класс год ангарск цвет чёрный стоимость тыс р хэтчбек акпп пробег тыс км',
#  'евгений маргулис таня дура',
#  'видео',
#  'дальномер всё объявление продажа',
#  'принцесса спорт предмет',
#  '',
#  '',
#  'просмотр увеличить картинка загрузить фото картинка изображение',
#  'чемпионат мир собака пройти всемирный выставка',
#  'секс монстр часть порно комикс',
#  'купить грузовик камаз цена грузовик тонна фото',
#  'тетрадь упражнение русский язык класс галина мисаренко рецензия отзы',
#  'гдз математика класс мишакина задание стр',
#  'газовый горелка цена рубль отзыв фото выбор параметр каталог модель интернет магазин всеинструменты ру',
#  'лиса ставрополь',
#  'поле тетрадь чертить вручную',
#  'скачать песня зарядка ребёнок танец маленький утёнок бесплатно слушать онлайн',
#  '',
#  'оценка результат велоэргометрии норма показатель велоэргометрии',
#  'м москва фоторесурсы',
#  'рождественский коллекция макияж г л этуаль чернокнижница',
#  'спасибо покупка',
#  'каждый раунд игрок выдаваться деньга',
#  'купить электропривод неликвид',
#  '',
#  'тест страница лайфхакер',
#  'скидка интернет магазин',
#  'фен характеристика технический описание интернет магазин м видео москва',
#  'скачать бесплатно',
#  'коттедж дом участок',
#  'погода углицком час подробный прогноз погода чесменский район челябинский область россия',
#  'коса рыбий хвост заплести',
#  'звезда молодежки анна михайловский нежно поздравить брат совершеннолетие летидор',
#  'шаль палантин накидка запись рубрика шаль палантин накидка дневник нат',
#  'текст песня тирольский йодль звук музыка перевод слово песня видео клип',
#  'юрий яков калининград',
#  'салон красота красотка автовской улица санкт петербург официальный сайт',
#  'скин актив крем мл цена москва рубль',
#  'петропавловск камчатский всё вопрос перевозка автомобиль регион решать автомат седан бу',
#  'дмц научить жить текст песня',
#  'палатка навес купить доставка великобритания',
#  'купить складный велосипед феникс велосипед дюймовый складный велосипед взрослый скорость переменный скорость мужской женски',
#  '',
#  'поиск',
#  'спрей грунт серый мл автоцвет',
#  'окно пластиковый х камерный глухой размер мм тамбов',
#  'подполковник устюгов млн результат поиск',
#  'елена зеленская последний новость тег елена зеленская',
#  'купон руб оплата оправа',
#  'парень элина свитолиной фото новый причёска гаэля монфиса сегодня',
#  'скачать альбом сборник песня бесплатно',
#  'поиск почта',
#  'снять квартира слуцк длительный срок посредник сдать квартира слуцк длительный срок',
#  'продажа авто мицубиси монтеро спорт омск продажа собственник омский область руль левый л вд цена тысяча руб дилер бензин',
#  'результат поиск сырок александров',
#  'резаный огурец мариновать зима пошаговый рецепт фото',
#  '',
#  'скачать труба стальной электросварной оцинковать повышенный коррозионный стойкость технический условие',
#  'рамочка счастливый обсуждение российский сервис онлайн дн',
#  'скачивание зацепить минус',
#  'презентация аз л п н нен мара ак л ор ы туралы',
#  'канцелярский принадлежность интернет магазин палитра',
#  'имя часть первый',
#  'список поставщик продукт питание',
#  'международный фотоконкурс',
#  '',
#  'видео',
#  'женский кроссовок белые интернет магазин',
#  'отзыв покупатель',
#  'барулин почта',
#  'ботинок звёздный война демисезонный детский обувь владивосток',
#  'постановление декабрь г дело судакт ру',
#  'основа шахтный аэромеханика студопедия',
#  'инструкция порядок совершение нотариальный действие нотариус млн результат поиск',
#  'торрент порно скачать скачать порно хентайная эротический',
#  '',
#  'федеральный поставщик запчасть строительный оборудование бензо электро инструмент садовый техника клинингового уборочный оборудование',
#  'виктория гетто волк стая страница читать',
#  'цементный стружечный плита строительство частный дом статья интернет магазин материк',
#  'аренда автобетононасоса витебск сравнить цена заказать услуга маркетплейсе',
#  'скачать песня джемма халид',
#  'дизайн детский комната поиск',
#  'цена система руб москва купить бесплатный доставка вытяжка система прочить',
#  '',
#  'видео лариса м видео смотреть онлайн мир',
#  'шаровой опора автозапчасть нерюнгри',
#  'голый дамочка садиться волосатый пилотка лицо партнёр пол',
#  '',
#  'муж сестра порно видео',
#  'парка екатеринбург',
#  'платье брюки акцент талия носить осень мода стиль',
#  'салон одежда обувь самара куйбышев',
#  'сериал родитель сезон серия смотреть онлайн видео сериал фитнес сезон хороший качество видеохостинг',
#  'вакансия машинист насосный установка комсомольск амур работа компания амур золото работа вахтовый метод',
#  'приложение консультантплюс',
#  'дом новость слух саша гозиас привезти проект свой мать маленький дочь',
#  'поздравление год подруга',
#  'выжить любой цена замбия смотреть онлайн видео хороший качество видеохостинг',
#  'видео домашний мамочка зрелый дама секс игрушка бабушка',
#  '',
#  'инструкция тыс результат поиск',
#  'победитель всероссийский конкурс молодой учитель стать педагог мо телеканал',
#  'спасибо покупка',
#  'перемещение прямолинейный равноускоренный движение',
#  'футболист брено филип карточка игрок футбольный онлайн менеджер живить футбол',
#  'шлифовальный работа самара',
#  'видеокарта гб тыс результат поиск',
#  'наполеон хилл скачать аудиокнига думать богатеть скачать бесплатно читать онлайн слушать аудиокнига',
#  'дом адрес г подольск ул долгий',
#  'мир',
#  'скачать песня',
#  'тестовый задание английский язык класс',
#  'агентство реклама печать полиграфия ксерокопия ламинирование цифровой печать сувенирный продукция нанесение логотип разный продукция наружный реклама вывеска стенд',
#  'грибочек лесочек страница уаз патриот сибирь',
#  'изучать спрос панты марал',
#  'галерея изображение бу чр спортивный школа олимпийский резерв хк сокол',
#  'кед высокий',
#  'рецензия фильм рэмбо последний кровь фильм тыс результат поиск',
#  'есенин',
#  'актуальность профилактика злостный нарушение установленный порядок отбывание',
#  'внеклассный мероприятие тема сущность самовоспитание результат',
#  'ловушка изобильный мышление',
#  'новокузнецк фото страница',
#  'решебник дидактический материал русский язык класс ульянов поиск',
#  'результат поиск школа дурак',
#  'фотография альбом пользователь',
#  'анна назарьева эротичекие фото актёр советский российский кино эротичес',
#  'ф р дэвид скачать бесплатно ф р дэвид',
#  'фильм ангел демон ангел демон актёр отзыв',
#  'газовый горелка свой рука вариант домашний дело газовый горелка свой рука',
#  'цсп отделение шахматы псков адрес улица свердлов телефон сайт реж',
#  'анатомия страсть',
#  'отклик соискатель',
#  'юбилей мужчина',
#  'методический указание выполнение работа дисциплина эффективный поведение н',
#  'екатерина коб голый тыс результат поиск',
#  'результат поиск',
#  'считыватель карта',
#  'неустойка ст гк рф формула расчёт неустойка залог внесудебный реализация гарантия задаток др способ обеспечение казахстанский',
#  'слушать русский радио россия г москва поп музыка',
#  'скорость свет вакуум невозможность распространение информация быстрый',
#  'класс презентация история каталог файл сайт учитель история обществознание',
#  '',
#  'мбуз городской поликлиника г ростов дон инна огрн',
#  '',
#  'заводиться замена топливный фильтр страница',
#  'секрет красота уход',
#  'восточный европейский овчарка фото восточный европейский овчарка общий вид восточник тип конституция рост восточный европейский поведени',
#  'дешёвый авиабилет онлайн',
#  'сборная союз час женатый слушать скачать бесплатно',
#  'домик питомец',
#  'победа локомотив позволить россия оторваться португалия таблица коэффициент уефа новость еврокубков футбол спорт',
#  'надувной лодка лоцман м рс цена руб купить минск',
#  'вощёный парусиновый сумка',
#  'радуга фиалка рм роса изумруд н скорнякова',
#  'писать онлайн тешиться ванная',
#  'продукция товар услуга компания фактор спецэлектроника',
#  'концепция жизненный мир э гуссерля герменевтический проблема тема научный статья философия читать бесплатно текст научно',
#  'мафик кент',
#  'запрос свитер вырез найти результат интернет магазин',
#  'проект безопасный качественный автомобильный дорога регион отремонтировать трасса новость пермь',
#  'сиренко аркадий василиевич это сиренко аркадий василиевич',
#  'положение порядок приём педагогический работник работа конкурсный основа муниципальный бюджетный учреждение дополнительный образование спортивный школа город ливны',
#  'королевский ватрушка рецепт вкусный выпечка',
#  'резинотехнический автокомпоненты премиум класс сайлентблок попереч',
#  'шить кожа набор изготовление кошелёк стандарт готовый набор',
#  'смартфон',
#  'сдавать комн квартира пр королева собственник сжм северный жилой массив ростов дон фото детский сад неагент',
#  'просмотр резюме',
#  'врип глава раменский район николай воробьёв обсудить житель благоустройство пруд главный новость подмосковье',
#  '',
#  'квартира вторичный рынок купить спб продажа квартира вторичке',
#  'смотреть клетка сезон бесплатно онлайн',
#  '',
#  'тапочки носка пинетка запись рубрика тапочки носка пинетка дневник нина',
#  'мир',
#  'б ограф нум рапас',
#  'дэвид вебер восстание читать онлайн',
#  'фильм высоцкий спасибо живой высоцкий смотреть онлайн бесплатно российский фильм сериал кино театр ру',
#  'книга записка хвостатый звезда читать онлайн евгений чепенко страница',
#  'лоадеры укра н пора вняти ц придбати споживч товари маркетплейс',
#  'снежинка бумага любовь париж',
#  'отзыв личный опыт',
#  '',
#  'архангельский опытный водорослевый комбинат',
#  'вольга микула селянинович гипербола эпитет повтор приве',
#  'биквадратный уравнение алгоритм решение пример',
#  'кнопочка москва год фото страница',
#  'юрист защита право потребитель москва бесплатный консультация юрист защита право потребитель',
#  'скачать торрент ролик',
#  'мультфильм онлайн смотреть бесплатно хороший мультик хороший качество',
#  'фото виторгана нинидзе греция экспресс газета',
#  '',
#  'точно скачать песня бесплатно',
#  'отчёт матч',
#  'краснодарский край результат поиск страница',
#  'сенсор датчик автоматизация здание помещение умный дом страница',
#  'ботинок купить руб интернет магазин',
#  'конструктор паровозик астротойз',
#  'макрон хотеть создать альянс доверие германия избежание распад ес европа новость день',
#  'постановление октябрь г дело судакт ру',
#  '',
#  '',
#  '',
#  'сие таррэн феррис аканехиде',
#  'декасан состав препарат помогать стомалогории бронхит ангина применять беременность ребёнок цена аналог',
#  'дорога попутчик хлопоты',
#  'чёрный босоножка блочный каблук',
#  'форум кукла',
#  'грамотно расставить мебель маленький кухня использовать всё пространство',
#  'вакансия студент город санкт петербург работа гибкий график',
#  'полный вагин сперма онлайн смотреть бесплатно порно видео онлайн',
#  'цена руб купить москва',
#  'отзыв сбербанк россия двойной списание средство мобильный банк банк ру',
#  'телок питер знакомство новый друг сниматься крутой домашний порн',
#  'русский язык класс ладыженская м баранов ч номер',
#  'иерусалимский королевство всё монархия мир',
#  'отучить лайк поедать трепать битый дичь зверёк',
#  'сайт знакомство',
#  'россия санкт петербург м лесной',
#  'сервис доступный',
#  'термо комбинезон мальчик французский грн одежда мальчик киев',
#  'редактировать товар личный кабинет',
#  'коттедж дом участок',
#  'порно видео онлайн мина',
#  'стих ребёнок зимовать животное',
#  'уайат сенак разрулит сезон серия смотреть онлайн беспла',
#  'тюменский дизайнер ален дубровин получить гран москва новость тюмень',
#  'кот морда вниз',
#  'администратор отель',
#  'ооо группа компания михайлов партнёр москва инна огрн',
#  'сергей скрипаль контингент книга афган читать онлайн',
#  '',
#  '',
#  'кислота фармакология',
#  'читать манга боевой континент страна душа глава русский онлайн',
#  'продаваться ссангйонг рекстон год томск собственник владеть год литр бензин акпп',
#  'запчасть грузовой легковой автомобиль оборудование сто',
#  'нордрута пододеяльник наволочка серый синий',
#  'манга онлайн',
#  'продать батарея грн отопление харьков',
#  'автозапчасть город дюссельдорф германия каталог магазин автозапчастей адрес телефон время работа сайт',
#  'вакансия инженер видеонаблюдение серов работа компания угмк холдинг полный рабочий день',
#  'секс выпускной вечер',
#  'скачать порно длинноволосый красотка телефон',
#  'мег монстр глубина скачать торрент файл бесплатно',
#  'решить упр урок гдз кузовлев класс перевод задание',
#  'анатоль год лев плещеницы анкета знакомство сайт',
#  'крахмал загуститель заменитель полезный очень выглядеть',
#  'сдать ю квартира июнь грн долгосрочный аренда квартира комната ильичевск',
#  'серия сезон мультсериал гриффины озвучке студия игра свидание смотреть гриффины онлайн качество',
#  'далее',
#  '',
#  'расстояние ростов дон феодосия км маршрут',
#  '',
#  'тюнинг казань сравнить цена купить потребительский товар маркетплейсе',
#  'сонник картинка скелет сниться картинка скелет видеть сон сонник дом',
#  'рс русский скачать торрент программа бесплатно регистрация',
#  'купальник бикини двухцветном дизайн размер чёрный серый',
#  'обмен скот тг нур султан астана',
#  'скачать бесплатно слушать онлайн видеок',
#  'современный технология обучение музыкальный образование тема научный статья народный образование педагогика читать бесплатно',
#  'человек седан мигрант погибнуть пытаться покинуть гаити',
#  '',
#  'урок класс тема повторение систематизация изучить имя существительное бюджетный общеобразовательный учреждение вышний ольшанский средний общеобразовательный школа',
#  'транспортный налог ветеран боевой совет адвокат юрист',
#  'балаба ша жасында ы балалар арнал ан таныстыру ра жауап',
#  'коттедж новый год загородный отдых',
#  'салат гранатовый',
#  'блондинка больший сиська изнасиловать бдсм игра',
#  'руководство издание четвёртый дополнить переработать',
#  '',
#  '',
#  'проблема сцепление камаз дальнобойщик весь страна объединяться',
#  'барахолка уфа',
#  'отзыв антиперспирант',
#  'профиль пользователь путешествие отдых',
#  'связаться оператор триколор тв тыс результат поиск',
#  'запрашивать страница найти',
#  'профиль пользователь фото сайт',
#  'рс русский скачать торрент игра бесплатно регистрация',
#  '',
#  '',
#  'решение м м сентябрь г дело судакт ру',
#  'тип заинтересоваться дырка опытный женщина выебал диван',
#  'пословица поговорка день неделя',
#  '',
#  'суккулент крассула купер растение владивосток',
#  'сервисный компания буттэк отзыв фото цена телефон адрес сервисный центр москва',
#  'фото кпб поплин византия графит цена руб отдать руб',
#  'доставка продукт дом елизово камчатский край адрес телефон карта проезд',
#  'продаваться автобус автобус комсомольск амур',
#  '',
#  '',
#  '',
#  'саратов дача снт архитектор тыс результат поиск',
#  'детский лагерь огонёк сергиево посад оздоровительный лагерь огонёк детский отдых',
#  'мать смотреть отец трахать красавица дочь',
#  'читать онлайн книга единственный барс бесплатно страница',
#  'купить серебряный браслет беларусь',
#  'сонник смотреть мультфильм присниться сниться смотреть мультфильм сон видеть',
#  'почта',
#  'р ама голый гс дс коса мис ебенка',
#  'программа бесплатный создание сайт движок программный оболочка денвер создание виртуальный хостинг домашний комп',
#  'фёдор бондарчук паулина андреев сыграть свадьба петербург',
#  'автокран ивановец кс р шасси камаз тонна',
#  'смотреть видео онлайн мир',
#  'ружьё хороший мр сайга популярный оружие',
#  'ребёнок ясли обучать инновационный программа российский газета',
#  'знакомство нерюнгри сайт знакомство шура мур',
#  'насос электрический купить москва цена фото отзыв характеристика',
#  'работа поиск работа минск беларусь',
#  'шар латексный',
#  'гласный буква класс конспект презентация урок фгос готовый млн результат поиск',
#  'гифки поиск сайт',
#  'перевод пример предложение',
#  'галерея',
#  'ужас страница',
#  'октябрьский почта',
#  'реклама',
#  'бетостоун быстросохнущий двухкомпонентный полиуретановый грунт эмаль компания рифорн купить город екатеринбург',
#  'поиск работа вакансия зарплата ру',
#  'качать шашка',
#  'фигурка оникс значение древность современность удача',
#  'образ обеспечиваться защита право ребёнок рф защита право ребёнок российский федерация',
#  'золото древний русь черняев ф',
#  'расстановка герой альянс человек воин чешуйчатый охотник неуловимый убийца',
#  'оперативный цифровой типография краснодар',
#  'каждый тыква',
#  'скачать фильм звёздный путь телефон',
#  '',
#  'скачать смотреть онлайн',
#  'поезд самолёт почта',
#  'запчасть блендер деталюга',
#  'система оповещение управление эвакуация статья омега саунд россия',
#  'программа обучение охрана труд',
#  'толкование карта таро разный страница тонкий мир эзотерический форум магия гороскоп гадание заговор приворот сонник астр',
#  'крестный отец пьюзо м купить амиталь доставка',
#  'порадовать жопа аделин ишим район сто',
#  'мир',
#  'подбор шина автомобиль',
#  'сварщик пластмасса еткс',
#  'фото альбом фото группа фото фотография вязание',
#  '',
#  'фото тула',
#  'снабженец экспедитор водитель',
#  'видео михаил кононенко видео смотреть онлайн мир',
#  'эмблема',
#  '',
#  'купить тормозной система томск сравнить цена тормозной система томск',
#  'купить дышать подкладочный ковёр битумный черепица фальцевую кровля натуральный сланец цена москва',
#  'блондинка пышный грудь заниматься секс муж свадьба',
#  'сериал обезьяна сезон смотреть онлайн бесплатно хороший качество',
#  'юленька год россия альметьевск социальный сеть позволять знакомиться общятся человек отправлять смс ещё',
#  'видео молодой русский порно больший дырка мастурбация красотка',
#  'новый современный обезболивание животное',
#  'знакомство рига ольга год бесплатный сайт знакомство датинг ру бесплатный мобильный сайт знакомство серьёзный отношение',
#  '',
#  'шнур далее',
#  'анальный азиатка закатить глаз кончить секс',
#  ...]

# %% [markdown]
# # CountVectoriser

# %%
vectorizer = CountVectorizer(lowercase=True, stop_words=stop_words)

X_train_vectorized = vectorizer.fit_transform(X_train)

X_train_vectorized
# Out:
# <135309x189711 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1120352 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## LogisticRegression

# %%
model = LogisticRegression()

# %%
# %time

model.fit(X_train_vectorized, y_train)

y_pred = model.predict(X_train_vectorized)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.25 µs

# %%
f1_score(y_train, y_pred)
# Out:
# 0.9746839317966144

# %%
X_test_vectorized = vectorizer.transform(X_test)

test_df["target"] = model.predict(X_test_vectorized).astype(bool)

test_df[["id", "target"]].to_csv("log_reg.csv", index=False)

# !cat ml_baseline.csv | head
# Out:
# id,target
# 135309,False
# 135310,False
# 135311,False
# 135312,True
# 135313,False
# 135314,False
# 135315,False
# 135316,False
# 135317,False
# cat: write error: Broken pipe

# %% [markdown]
# ## SGDClassifier

# %%
model = SGDClassifier()

# %%
# %time

model.fit(X_train_vectorized, y_train)

y_pred = model.predict(X_train_vectorized)
# Out:
# CPU times: user 1e+03 ns, sys: 1 µs, total: 2 µs
# Wall time: 3.81 µs

# %%
f1_score(y_train, y_pred)
# Out:
# 0.9574494479593103

# %%
X_test_vectorized = vectorizer.transform(X_test)

test_df["target"] = model.predict(X_test_vectorized).astype(bool)

test_df[["id", "target"]].to_csv("SGD.csv", index=False)

# !cat ml_baseline.csv | head
# Out:
# id,target
# 135309,False
# 135310,False
# 135311,False
# 135312,True
# 135313,False
# 135314,False
# 135315,False
# 135316,False
# 135317,False
# cat: write error: Broken pipe

# %% [markdown]
# ## ComplementNB

# %%
model = ComplementNB()

# %%
# %time

model.fit(X_train_vectorized, y_train)

y_pred = model.predict(X_train_vectorized)
# Out:
# CPU times: user 0 ns, sys: 1e+03 ns, total: 1e+03 ns
# Wall time: 4.53 µs

# %%
f1_score(y_train, y_pred)
# Out:
# 0.8324219348903767

# %% [markdown]
# ## MultinomialNB

# %%
model = MultinomialNB()

# %%
# %time

model.fit(X_train_vectorized, y_train)

y_pred = model.predict(X_train_vectorized)
# Out:
# CPU times: user 1e+03 ns, sys: 1e+03 ns, total: 2 µs
# Wall time: 2.86 µs

# %%
f1_score(y_train, y_pred)
# Out:
# 0.9097784676167632

# %% [markdown]
# # TfidfVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(lowercase=True, ngram_range=(2, 4), analyzer='char', min_df=5, max_df=0.8)

X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.fit_transform(X_test)

# %% [markdown]
# ## LogisticRegression

# %%
model = LogisticRegression(class_weight='balanced')

# %%
# %time

model.fit(X_train_tfidf, y_train)

y_pred = model.predict(X_train_tfidf)
# Out:
# CPU times: user 1e+03 ns, sys: 1e+03 ns, total: 2 µs
# Wall time: 4.29 µs
# /home/ilya/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
f1_score(y_train, y_pred)
# Out:
# 0.9756068784473351

# %%
test_df["target"] = model.predict(X_test_tfidf).astype(bool)

test_df[["id", "target"]].to_csv("log_reg_tfidf.csv", index=False)

# !cat ml_baseline.csv | head
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 test_df["target"] = model.predict(X_test_tfidf).astype(bool)
#       3 test_df[["id", "target"]].to_csv("log_reg_tfidf.csv", index=False)
#       5 get_ipython().system('cat ml_baseline.csv | head')
#
# File ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_base.py:425, in LinearClassifierMixin.predict(self, X)
#     411 def predict(self, X):
#     412     """
#     413     Predict class labels for samples in X.
#     414
#    (...)
#     423         Vector containing the class labels for each sample.
#     424     """
# --> 425     scores = self.decision_function(X)
#     426     if len(scores.shape) == 1:
#     427         indices = (scores > 0).astype(int)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_base.py:407, in LinearClassifierMixin.decision_function(self, X)
#     387 """
#     388 Predict confidence scores for samples.
#     389
#    (...)
#     403     this class would be predicted.
#     404 """
#     405 check_is_fitted(self)
# --> 407 X = self._validate_data(X, accept_sparse="csr", reset=False)
#     408 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     409 return scores.ravel() if scores.shape[1] == 1 else scores
#
# File ~/.local/lib/python3.8/site-packages/sklearn/base.py:585, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     582     out = X, y
#     584 if not no_val_X and check_params.get("ensure_2d", True):
# --> 585     self._check_n_features(X, reset=reset)
#     587 return out
#
# File ~/.local/lib/python3.8/site-packages/sklearn/base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 193067 features, but LogisticRegression is expecting 173100 features as input.

# %% [markdown]
# ## SGDClassifier

# %%
model = SGDClassifier()

# %%
# %time

model.fit(X_train_tfidf, y_train)

y_pred = model.predict(X_train_tfidf)
# Out:
# CPU times: user 1e+03 ns, sys: 1e+03 ns, total: 2 µs
# Wall time: 3.34 µs

# %%
f1_score(y_train, y_pred)
# Out:
# 0.8902786049897427

# %% [markdown]
# ## ComplementNB

# %%
model = ComplementNB()

# %%
# %time

model.fit(X_train_tfidf, y_train)

y_pred = model.predict(X_train_tfidf)
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 4.77 µs

# %%
f1_score(y_train, y_pred)
# Out:
# 0.8414519662042348

# %%
test_df["target"] = model.predict(X_test_tfidf).astype(bool)

test_df[["id", "target"]].to_csv("ComplementNB_tfidf.csv", index=False)

# !cat ml_baseline.csv | head
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [40], in <cell line: 3>()
#       1 X_test_tfidf = tfidf_vectorizer.fit_transform(X_test)
# ----> 3 test_df["target"] = model.predict(X_test_tfidf).astype(bool)
#       5 test_df[["id", "target"]].to_csv("ComplementNB_tfidf.csv", index=False)
#       7 get_ipython().system('cat ml_baseline.csv | head')
#
# File ~/.local/lib/python3.8/site-packages/sklearn/naive_bayes.py:82, in _BaseNB.predict(self, X)
#      68 """
#      69 Perform classification on an array of test vectors X.
#      70
#    (...)
#      79     Predicted target values for X.
#      80 """
#      81 check_is_fitted(self)
# ---> 82 X = self._check_X(X)
#      83 jll = self._joint_log_likelihood(X)
#      84 return self.classes_[np.argmax(jll, axis=1)]
#
# File ~/.local/lib/python3.8/site-packages/sklearn/naive_bayes.py:519, in _BaseDiscreteNB._check_X(self, X)
#     517 def _check_X(self, X):
#     518     """Validate X, used only in predict* methods."""
# --> 519     return self._validate_data(X, accept_sparse="csr", reset=False)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/base.py:585, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     582     out = X, y
#     584 if not no_val_X and check_params.get("ensure_2d", True):
# --> 585     self._check_n_features(X, reset=reset)
#     587 return out
#
# File ~/.local/lib/python3.8/site-packages/sklearn/base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 216024 features, but ComplementNB is expecting 189852 features as input.
