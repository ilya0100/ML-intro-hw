# %%
import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv("train.csv")

train_df
# Out:
#             id                        url  \
# 0            0                    m.kp.md
# 1            1                  www.kp.by
# 2            2              fanserials.tv
# 3            3            colorbox.spb.ru
# 4            4              tula-sport.ru
# ...        ...                        ...
# 135304  135304                    mail.ru
# 135305  135305                 www.ntv.ru
# 135306  135306  topclassiccarsforsale.com
# 135307  135307                wowcream.ru
# 135308  135308                 www.ubu.ru
#
#                                                     title  target
# 0       Экс-министр экономики Молдовы - главе МИДЭИ, ц...   False
# 1       Эта песня стала известна многим телезрителям б...   False
# 2       Банши 4 сезон 2 серия Бремя красоты смотреть о...   False
# 3                                   Не Беси Меня Картинки   False
# 4       В Новомосковске сыграют следж-хоккеисты алекси...   False
# ...                                                   ...     ...
# 135304  пора тюльпанов турецкий сериал на русском язык...   False
# 135305  Остросюжетный сериал «Шеф. Игра на повышение»....   False
# 135306  1941 Plymouth Special Deluxe Hot Rod, Automati...   False
# 135307  Купить It's Skin Сыворотка питательная Power 1...   False
# 135308  Технический спирт в канистрах и флаконах, купи...   False
#
# [135309 rows x 4 columns]

# %%
len(train_df)
# Out:
# 135309

# %%
test_df = pd.read_csv("test.csv")

test_df.head()
# Out:
#        id                url  \
# 0  135309  www.kommersant.ru
# 1  135310    urexpert.online
# 2  135311      imperimeha.ru
# 3  135312  national-porn.com
# 4  135313            2gis.ru
#
#                                                title
# 0  Шестой кассационный суд в Самаре начнет работу...
# 1  Что такое индексация алиментов, кем и в каких ...
# 2                  Женщинам | Империя Меха - Part 12
# 3  Небритые, волосатые киски: Порно всех стран и ...
# 4                                                 67

# %%
len(test_df)
# Out:
# 165378

# %%
train_df["target"].value_counts()
# Out:
# False    118594
# True      16715
# Name: target, dtype: int64

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/ilya/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import re
import pymorphy2

from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB, ComplementNB
from sklearn.preprocessing import StandardScaler

# %%
TOKEN_PATTERN = "[а-яё]+"
SEED = 42

# %%
stop_words = nltk.corpus.stopwords.words("russian")

# %%
X_train = train_df["title"].values
X_test = test_df["title"].values
y_train = train_df["target"].astype(int).values

# %%
def tokenize(text):
    return re.findall(TOKEN_PATTERN, text.lower())

# %%
lemmatizer = pymorphy2.MorphAnalyzer()

lemmatizer_cache = {}

def lemmatize(token):
    if lemmatizer.word_is_known(token):
        if token not in lemmatizer_cache:
            lemmatizer_cache[token] = lemmatizer.parse(token)[0].normal_form
        return lemmatizer_cache[token]
    return token

# %%
X_train_tokenized = [tokenize(text) for text in X_train]

X_train_lemmatized = [[lemmatize(token) for token in text] for text in X_train_tokenized]

X_train_cleared = [" ".join([token for token in text if token not in stop_words]) for text in X_train_lemmatized]

# %%
X_train_cleared
# Out:
# ['экс министр экономика молдова глава мидэи цель который сделать республика проситель донор избегать долгий нахождение н',
#  'песня стать известный многий телезритель благодаря сериал диверсант',
#  'банши сезон серия бремя красота смотреть онлайн',
#  'бесить картинка',
#  'новомосковск сыграть следж хоккеист алексинский звезда сборная китай',
#  'салат корейский морковь копчёный курица кукуруза сухарик калорийность белка жир углевод',
#  'угловой пневмогайковерт екатеринбург купить цена отзыв характеристика фото инструкция',
#  'табачный магазин мир табак курительный трубка курительный труба',
#  '',
#  'р одесса ростов дон сентябрь фаворит чп',
#  'огэ математик функция задача ответ готовый',
#  'мировой экономика схема таблица млн результат поиск',
#  'кримпай мать сын страница смотреть порно мультик порно комикс хентай онлайн бесплатно',
#  'мария шорох право выбор академия си читать онлайн',
#  'днепр наслать пропасть летний девушка',
#  'мир',
#  'слава медяник стучать колесо',
#  'инженерный институт казанский приволжский федеральный университет учёба ру',
#  'каков основной черта размещение отрасль топливный промышленность территория россия млн результат поиск',
#  'мужик поставить блондинка рак отодрать тугой очко порно видео',
#  'портер джейн звёздный дождь скачать бесплатно книга формат',
#  'порно который искать видео',
#  'услуга городской номер подключить мобильный билайн ульяновск',
#  '',
#  'погода сочи сентябрь тыс результат поиск',
#  'погода гостомел дн прогноз погодить дн рп нь ки вська область укра',
#  'служба поддержка',
#  'учётный запись нальчик',
#  'кожа волос ноготь результат поиск',
#  'форма наряд допуск производство работа место действие опасный вредный фактор снип безопасность труд строительство часть первый',
#  'ласточка аккорд текст видео',
#  'школьный форма солнце мода чёрный цвет цена руб купить гомель',
#  'диалог',
#  'купить встраив газовый панель каталог интернет магазин м видео выгодный цена доставка отзыв фотография вести',
#  '',
#  'форма леденец шоколад курочка ряба купить',
#  'погода ноябрь новость казахстан',
#  'видео видео',
#  '',
#  '',
#  'отзыв домкрат подкатной гидравлический онт удобный тяжёлый домкрат',
#  'лесбийский секс кунилингусом стройный студентка высококачественный порно видео участие эмиль блум',
#  'презентация тема приблизить значение абсолютный относительный погрешнос',
#  'горбачёв октябрь намеренный участвовать заседание иск жириновский политика тасс',
#  'москва марокко ночь руб',
#  'гоша матарадзе сердце слушать бесплатно онлайн',
#  'миска салатник страница',
#  '',
#  'мельница крупорушка заводский изготовление квт срочно грн оборудование кременчуг',
#  '',
#  'изюминка лимончик обычный',
#  'снять быстросъем печка фокус тыс результат поиск',
#  '',
#  '',
#  'маленький характер частный детский сад детский центр хорошево мнёвники',
#  '',
#  'фото голый девочка бесплатный эротика',
#  'порно видео эротический фильм малолетка',
#  'свет свет оренбург оренбургский обл россия год мир',
#  'вакансия микролаб системс москва работа микролаб системс',
#  'ассасинавт скачать торрент хороший качество',
#  'ведущий специалист закупка',
#  'дима билан сняться фильм андрей кончаловского',
#  'русский наследница сезон смотреть онлайн хороший качество',
#  'купить беговой дорожка квартира интернет магазин зона спорт интернет м',
#  'профессия стыковщик текстиль пресса описание зарплата',
#  'фото пейзаж пейзажный фотография страница социальный сеть фотокто',
#  'бишунму танцующий небо серия сезон смотреть онлайн',
#  'характеристика различный вид перевозка груз буква ру научно популярный портал',
#  'кольцо инкрустация цирконий р р р позолота продажа цена ровно кольцо перстень оптовый интернет магазин позолотить бижутерия',
#  'судак затонуть прогулочный катер турист пассажирка погибнуть яплакалъ',
#  'общий положение консультантплюс',
#  'фильм смешной девчонка смотреть онлайн полностью качество бесплатно',
#  'начало смотреть онлайн бесплатно хороший качество',
#  'фильм артек фото видео список актёр вокруг тв',
#  'разбирать принтер замятие бумага аналогичный принтер смотреть видео онлайн',
#  'воровайки мурки воровайки клип смотреть онлайн',
#  'восход заход солнце астана тыс результат поиск',
#  'блокування мост метро кличко розпов що м нувальник мав серйозн ри перебував стан сп ян ння новини ки ва ки',
#  'книга магия поцелуй морить триша литлайф книга читать онлайн скачать бесплатно полный книга',
#  'читать манга крутой учитель онидзука глава русский онлайн',
#  'читать манга друг мир имя чёрный целитель глава русский онлайн',
#  'кр улуттук банкынын нарын облустук башкармалыгынын филиалынын улук бухгалтери токтакунова кызматынан негизсиз четтетилген кабар кыргыз улуттук маалымат агенттиги',
#  '',
#  'изумрудный сказка эсми никс ямогу каталог мастер автор кукла игрушка кукольный одежда аксессуар бэйбики кукла фото одежда кук',
#  'рисовый каша вода рецепт фото',
#  'горный болезнь',
#  'супервайзер книга супервайзер увеличить объём продажа',
#  '',
#  'натуральный волос',
#  'назвать человек думать большой',
#  'фильтр страница',
#  'пол пола пол закупка этап подача заявка пермь пермский край пермский р н',
#  'м ф ромео обочина индия',
#  'росфинмониторинг почта',
#  'порошенко п дписав антирейдерський земельний закон укра нська правда',
#  'морковный палочка',
#  'государственный музей л н толстой гмт элкос дизайн',
#  'рамблер касса',
#  'шикарный молодой женщина обнажённый соска эротика фото голый целоваться девушка раздетый женщина',
#  'фото фото фотография олеся швецов',
#  'строительство коттедж пенобетон ключ омскдом',
#  'военный тематика страница скачать книга формат бесплатн',
#  'магазин электронный компонент электронщик продажа электронный компонент радиодеталь измерительный техника светотехнический',
#  'сушка дерево вакуумный камера',
#  'срок поставка киа пиканто субкомпактный автомобиль',
#  'почтовый индекс улица лев толстой санкт петербург номер дом',
#  'комплект муравьиный ферма горный мох купить белгород интернет магазин',
#  '',
#  'презентац сутн сть маркетинг його визначення',
#  'марсель муратов казань татарстан россия год мир',
#  '',
#  'администрация дк',
#  'город холм',
#  'челябинский область появиться ещё виртуальный концертный зал',
#  'анжелика агурбаш любовь твой мало музыка скачать бесплатно слушать музыка анжелика агурбаш любовь твой мало песня песня онлайн',
#  'необычный рецепт вкусный идея каждый день',
#  'девчата радость пописать туалет сообщение москва',
#  'гостиница авс отель россия свердловский область екатеринбург цена',
#  'купить кронштейн тв наклонно поворотный каталог интернет магазин м видео выгодный цена доставка отзыв фотогра',
#  '',
#  'технический функциональный возможность интерактивный доска тема научный статья общий комплексный проблема естественный точн',
#  'секс знакомство обмен интим фото регистрация бесплатно смс',
#  'смотреть онлайн',
#  'подсказать ваш ребёнок написать централизовать работа геометрия который наш класс поход очень',
#  '',
#  'азаров английский язык младший школа скачать беслатно учебник тетрадь аудио карточка весь класс',
#  'ребёнок красный глаз гноиться ребёнок красный глаз гной',
#  'урал играть кёрлинг автомобиль око смотреть видео онлайн мир олег фролов',
#  'читать книга оригинал си страница библиотека книга',
#  'игра скачать торрент бесплатно регистрация',
#  'бархатцы махровый гигант гр цп семя алтай',
#  'смотреть видео онлайн мир',
#  'собака поезд укрзализныця объяснить правило перевозка животное сегодня',
#  'фильм жанр комедия смотреть онлайн бесплатно',
#  'реклама',
#  'ленинский район сентябрь состояться очередной заседание комиссия профилактика правонарушение',
#  'побег лос анджелес слушать скачать',
#  'таинственный лес тайна покрыть мрак отзыв',
#  'танцевальный клуб импульс белгород ребёнок год',
#  'скачать клуб винкс сезон серия обратно средний век русский никелодеон смотреть онлайн',
#  'мир',
#  'против язва',
#  'большой шар кукла купить краснодар цена руб дата размещение игрушка игра',
#  'интернет магазин женский мужской детский одежда обувь аксессуар онлайн доставка день бесплатный отправка заказ',
#  'соликамск база данные недвижимость соликамск сайт объявление продажа аренда объявление',
#  '',
#  'водитель элитный мерседес убийца который насмерть сбить парень бауманский экстрадировали мюнхен москва',
#  'тайный война воздушный штрафбата война художественный литература читать онлайн',
#  'отправление ответ объявление огосекс ру',
#  'результат поиск запрос секрет пластилин интернет магазин читать город',
#  'читать манга скала кен глава русский онлайн',
#  'крыло правый передний автозапчасть горный алтайск',
#  'акция пятёрочка завтрак каша машина ваш',
#  'колледж красноярск специальность преподавание начальный класс',
#  'натали инстаграм фотография',
#  'кожаный сумка купить интернет магазин домани',
#  'фильтр поиск',
#  'купить кабель пульт микрофон цена руб',
#  'читать',
#  'порно видео скачать смотреть фильм',
#  '',
#  'постоянно гореть ответ ремонт эксплуатация форум авто',
#  'передний энциклопедия',
#  'песня номад сезон выпуск фрагмент песня смотреть онлайн видео бесплатно видеохостинг',
#  'взрыв завод поставщик тойота сказаться производство компания россия',
#  'хороший цена деталь хороший цена поставщик деталь',
#  '',
#  'оператор получение входной данные пользователь процедура',
#  'студент який кинуть яйцо янукович роц дора директор департамент ода портал новина',
#  'бережинський ззсо ступен ровоградська область суо',
#  'луг фреш синюга',
#  'скачать андроид отзыв промокод деньга телефон рф',
#  'специальность сибгу м ф решетнёв направление образование бакалавриат языкознание литературоведение красноярск',
#  'атлантис тв кабельный телевидение гай адрес описание отзыв',
#  'гдз номер математик класс рабочий тетрадь г мерзляк б полонский',
#  'результат поиск запрос гарри потереть',
#  'девочка самый интересный фото дом солнце',
#  'портфель',
#  'й й',
#  '',
#  '',
#  'смотреть видео онлайн бесплатно',
#  '',
#  'общественный политический организация пенза ул титов организация',
#  'горячий закуска банкетный зал шартрез',
#  'офис сезон серия смотреть онлайн высокий качество',
#  'танк армата поступить армия экспресс газета',
#  'сырный дом всё домашний сыроделие',
#  '',
#  'читать книга спать красавица лп страница библиотека книга',
#  'ролевый игра жёстко ебёт далее жена',
#  'отзыв работа сеть кафе столовый подсолнух город новосибирск чёрный сп',
#  'девичий стройность почему француженка толстеть',
#  'сопр вариант дз часть студизба',
#  'класс тест доказательство эволюция',
#  'утверждение перечень государственный работа выполнять государственный учреждение владимирский область отношение который государственный инспекция охрана использование животное мир администрация область осуществлять функция полномочие',
#  'задание решение русский язык класс ладыженская',
#  'эбби глайнс читать книга онлайн бесплатно',
#  'услуга трубочист спб прочистка дымоход вентканалов',
#  'слив обучение форум социальный инженерия',
#  'поездка попутчик дать водитель',
#  'газэнергоавтоматика',
#  'идея создание новогодний уют дом',
#  'великий северный война программа виват история виват история подкаст',
#  'м цветаев никто отнять текст произведение',
#  '',
#  'порно русский секс домашний гей видео видео',
#  'закупка моуо отдел образование администрация куртамышский район',
#  'корова цвет обсуждение российский сервис онлайн дневник',
#  'погода тужаре прогноз погода тужар черниговский область козелецком район неделя украина',
#  'альбом это екатерина год россия екатеринбург сеть знакомство мамба',
#  'ремкомплект суппорт шкода октавия комплект направлять гильза купить киев цена киев автозапчасть абсолют авто абсолютный качество',
#  'зозуля дитяч п сн укра нськ дитяч п сн',
#  'результат поиск запрос железный хватка',
#  'скачать порно телефон дама цепь трахнуть ебальной машина свой друг',
#  'капернаум фильм онлайн бесплатно кинохолд',
#  'туника г душанбе блузка бесплатный объявление купить продать б',
#  'необходимый проверка безопасность',
#  'фотография бр фото мир',
#  'готовый перевод стать суперзвезда глава',
#  '',
#  'куртка утеплить купить руб интернет магазин',
#  'овертайм новый подвиг летний скол сборный испания аргентина выйти финал км баскетбол рт русский',
#  'училка стрингах молодой порно фото',
#  'технология производство жби кольцо бетон центр',
#  'артрозилен гель г заказать онлайн купить близкий аптека выгодный цена',
#  'секс бесплатно бесплатный секс видео онлайн каждый день',
#  'скачать онлайн игра обзор официальный сайт видео',
#  'плакат кипелов дар москва дарудар',
#  'файтеры',
#  'дом интерьер красивый дом квартира весь мир пуфик блог дизайн интерьер',
#  'тыс результат поиск',
#  'фотография юлиан тугалова фото мир',
#  'гранитный мойка кухня цвет песочный сантехника водоснабжение',
#  'защита обратный тяга мм около санкт петербург купить низкий цена отзыв характеристика фото инструкция',
#  'абориген отодрать шикарный девица половой оральный анальный щель отборный порно ебухе',
#  'скачать бесплатно электронный библиотека поиск книга',
#  'читать манга месть масамуне кун глава русский онлайн',
#  '',
#  'немного обычай нрав рай название доминикана страна мама',
#  'сергей жорин александр толмацкий собираться забирать ребёнок вдова децла',
#  'соединение труба корсис труба система установка колодец',
#  'взять заказ',
#  'ежедневно кыргызстанец умирать болезнь сердце эксперт',
#  '',
#  'де ла круз мелисса маскарад страница читать онлайн',
#  'поиск скраб тело',
#  'розбираю грн транспорт запчасть рава русский',
#  'прокат квадроцикл бизнес начать сколько заработать',
#  '',
#  'гдз английский язык класс баранов м страница',
#  'мода',
#  'кыргызча жан ырлар скачать бесплатно текст',
#  'нумерология',
#  'вредность вредничество непокорность язвительство новый естественный лечение',
#  'свадебный вечерний платье новочеркасск салон скарлетт новочеркасск',
#  '',
#  'светодинамический фонтан средний нижний царицынский пруд бирюлёво восточный',
#  'кент кил психопат достоверный рассказ человек жалость совесть раскаяние читать онлайн полностью литрес',
#  'маруся человек бояться показать нужный отпустить пусть бояться далёкий',
#  'свитер мэйбл звезда вязание страна мама',
#  'снеговик',
#  'птуп мартин бел предлагать груз перевозка беларусь',
#  '',
#  'бассейн каркасный прямоугольный смотреть цена грн купить киев',
#  'скомпилировать скрипт каталог файл айта',
#  'женатый парень отжарить молодой соседка втихаря свой жена',
#  'экологический пирамида биомасса численность',
#  'скачать файл',
#  'вакансия работа нормировщик участок тверь поиск работа городработ ру',
#  '',
#  '',
#  'повышенный выделение слизь женщина вид прозрачный выделение заболевание',
#  'танк всё фильм отзыв рецензия смотреть видео онлайн',
#  'автобусный тур бельгия минск цена',
#  'курица кабачок китайски рецепт пошаговый фотография',
#  'хореография ребёнок направление центр знаток',
#  '',
#  'разрушитель легенда сша сериал вебург',
#  'мамка белый нижний бельё удовлетворять бородатый парень спальня',
#  'нож бабочка принтер',
#  'автоматический установка пожарный сигнализация',
#  'николай запорожье год фото страница',
#  'большой козловский переулок далее карта москва',
#  'немолодой женщина показать волосатый вагин порно секс фото зрелый дамочка',
#  'русский порно смотреть российский порнуха бесплатно онлайн страница',
#  'порно видео каролина свитс',
#  'рассрочка трансплантация волос',
#  'й',
#  'наташа мищенко свадебный фотограф ставрополь россия',
#  'россия ужесточить контроль перевод карта карта',
#  'читать манга опасный любовь глава русский онлайн',
#  'людмила баснак алма ата казахстан мир',
#  '',
#  'кран кулер укра н пора вняти ц придбати споживч товари маркетплейс',
#  'альбом развитие речь запись пользователь василиса сообщество детский книга категория самый маленький',
#  'макс барский заняться любовь слушать бесплатно онлайн',
#  'мочь бегать одышка рассказывать',
#  'просклонять слово кроватка падеж безбукв ру',
#  'фотография анастасия соломонов фото мир',
#  'анданте сезон торрент сериал скачать бесплатно смотреть онлайн',
#  'технология покраска бетон',
#  'ставка рефинансирование ключевой ставка цб рф год таблица',
#  'читать манга восьмой сын мочь это принять глава русский онлайн',
#  '',
#  'фильм операция тушёнка смотреть онлайн бесплатно хороший качество',
#  'купить туалетный кабина х х м невинномысск невинномысск производитель',
#  'купить тонометр механический иад стетоскоп комплект аптека московский регион доставка сравнение цена аптекамос',
#  '',
#  'обои природа обои рабочий стол фото',
#  'трансформатор грн прочий электроника запорожье',
#  'худи спортивный худи капюшон больший наклданым карман кенгуру ткань одежда женщина',
#  'дорама цветочек ягодка смотреть онлайн русский озвучка результат поиск',
#  'скачать бесплатно песня',
#  'рожанец александр робертович физиотерапевт отзыв запись приём',
#  '',
#  'фото топ р новый цена р',
#  'разный магний стр запись пользователь марина сообщество благополучный беременность категория медикамент витамин процедура',
#  'черёмуховый сайт город североуральск',
#  'презентация тема построение курс математика умк перспективный начальный широта',
#  'сдаваться двухкомнатный квартира кв м екатеринбург вторчермет эскадронный ул руб месяц',
#  'вакансия работа дворник разнорабочий прямой работодатель москва поиск работа городработ ру',
#  'скачать песня бесплатно слушать онлайн',
#  'дроссельный заслонка газель купить барнаул цена новый бу контрактный запчасть авто газ газель',
#  'заготовка рецепт',
#  'отзыв покупатель',
#  'наталья москва',
#  'администратор',
#  'хороший светодиодный лента год топ рейтинг хороший',
#  'обои видео игра обои рабочий стол фотография видео игра',
#  'значение имя иннокентий кеш',
#  'работа поиск работа минск беларусь',
#  'гдз русский язык класс решебники ответ онлайн',
#  'комплексный центр социальный обслуживание население бологовский район структура центр',
#  'документ учёба',
#  'подсветка салон передний плафон цена руб купить санкт петербург',
#  '',
#  'профессор карапуз музична пригода бесплатно скачать',
#  'продать г пмр авторынок пмр молдова клаксон',
#  'визит осенний визит спектр кредо электронный библиотека асмодея',
#  'вакансия слесарить механосборочный работа тула работа витра',
#  'рукоделие картина образ рукодельница живопись картина современный художник',
#  'смешной картинка прикол комикс гиф анимация видео хороший интеллектуальный юмор',
#  '',
#  'нахальный пронырливый человек буква',
#  '',
#  '',
#  'тур отель турция аланья цена отзыв',
#  'объявление снять комнатный квартира район центральный город хабаровск аренда трехкомнатных квартира длительный срок найти',
#  'стоматология улыбка всевластие стоматолог улыбка зуб властел',
#  'перечень предохранитель компонетов блок реле предохранитель расположить панель управление руководство обслуживание ремонт',
#  '',
#  '',
#  'отзыв моделирующий паста тело похудение экспресс греческий талассо',
#  'дестабилизировать это дестабилизировать',
#  'стр работа нур султан объявление вакансия',
#  'мир',
#  'горло отоларингология здоровье',
#  'фото город бетлица россия фотография',
#  'версия',
#  'читать книга поцелуй горец автор монинг карен онлайн страница читать книга регистрация',
#  'спасибо покупка',
#  'надежда псков',
#  'оргия яхта море порно видео онлайн смотреть бесплатно',
#  'проверка отзыв сайт',
#  'аладдин мультфильм смотреть онлайн хороший качество бесплатно',
#  '',
#  '',
#  'преддипломный практика начальный школа',
#  'сковорода сотейник купить крым севастополь симферополь керчь феодосия ялта страница',
#  '',
#  '',
#  'конструктор строительный площадка купить тольятти цена руб дата размещение игрушка игра',
#  'хороший цена трос стояночный тормоз хороший цена поставщик трос стояночный тормоз',
#  'некоторый думать футбол это дело жизнь смерть совершенно разочаровать позиция футбол намного важный свободный мнение бло',
#  'скачать торрент',
#  '',
#  '',
#  'знакомство парень краснодарский край новороссийск результат поиск сайт знакомство тралоло',
#  'сказка поп работник балда пушкин читать онлайн',
#  '',
#  'ылым саласында ы сыйлы тара мена мемлекетт ылыми стипендиялар туралы аз стан республикасы мета н жыл ы широта лдедег аулысы',
#  'сонник новый отношение присниться сниться новый отношение сон видеть',
#  'куркума вага тност експерти назвать неспод ван користь але нюанси',
#  '',
#  'фото альбом фото группа фото фотография тренд',
#  'кондиционер волос заказать германия доставка',
#  'харампурнефтегаз получить право строительство объект харампурском месторождение',
#  'остров миагани последний бомба местонахождение',
#  'архитектурный вуз университет институт академия факультет саратовский область вуз архитектор учёба ру',
#  'авторизац портал',
#  '',
#  'спортмастер г санкт петербург трк жемчужный плаз петергофское шоссе далее г санкт петербург',
#  'урок музыка главный кит песня класс урок',
#  'извадете електричеството както сте избрать електрически длето универсальный инструмент работилница домашен фурнир',
#  'александра загран паспорт помочь',
#  'почта',
#  'синоним слово удержать вертикальный положение',
#  'читать манга макрофаг ломать канон глава русский онлайн',
#  '',
#  'начальный уровень гдз решебник физика класс',
#  'работа сфера транспорт автобизнес автосервис руб москва',
#  '',
#  'социальный сеть позволять знакомиться общятся человек отправлять смс ещё',
#  'фильм закон каменный джунгли фильм фото видео список актёр вокруг тв',
#  'бедный настя серия смотреть онлайн сериал красвью',
#  'обувь страница',
#  'мотоциклист погибнуть столкновение иномарка улица землячка сормовский район нижний новгород сентябрь год новость',
#  'плохой отзыв прочитать',
#  'приказ минобразования рф',
#  'электротриммер',
#  'страница любимый нежность читать онлайн юлия шкутова полно книга',
#  'схемка осенний красота лист мариэлла обсуждение',
#  'особенность межнациональный сношение хороший качество вид',
#  'фильм подвиг сила дух рамблер кино',
#  'аренда клад м сигнальный проезд москва свао р н отрадный м владыкино база циан объявление',
#  'погода актаныш сентябрь самый очный прогноз сентябрь гидрометцентр актаныш',
#  'разнообразие стиль творчество художник казимир малевич',
#  'блендер купить блендер бош цена отзыв интернет магазин ситилинк таганрог',
#  'мир',
#  'порно телеканал смотреть онлайн бесплатно',
#  'брать скидка всё промокод ваш промокод купон скидка',
#  'мужик развести чужой жена больший сиська',
#  'скачать тас икс фильм сериал игра клип музыка програм',
#  'слушать аудиои книга выжать бизнес всё млн результат поиск',
#  'миля трейлер русский',
#  'фистинг девушка латекс',
#  'китайский биокомпания создать свой первый клонировать котёнок техкульт',
#  'наглядный биохимия кольман г рем год библиотека медицинский л',
#  '',
#  'размер колесо размер колесо',
#  'читать онлайн бартш карина бирюзовый зима электронный библиотека',
#  'алалия методика работа безречевыми ребёнок',
#  'приговор суд ч ст ук рф судебный практика',
#  'масло загар солярий',
#  'серия аниме покорение горизонт озвучка смотреть онлайн',
#  'арсенал частный охранный предприятие челябинск комсомольский проспект дом',
#  'нога пизда видео',
#  'скачать бесплатно слушать онлайн',
#  'ой хто хто миколай любить скачать бесплатно песня качество слушать онлайн',
#  'короткий поздравление дочь день рождение',
#  'м',
#  '',
#  'аквариумистика ру книга аквариумистике секрет аквариумный рыбоводство',
#  'продажа трехкомнатной квартира м ул энтузиаст сургут хант мансийский ао база циан объявление',
#  'оказываться иисус христос выглядеть дело',
#  'точка лежать каждый различный плоскость доказать точка лежать прямой',
#  'отбойный молоток минск продавец магазин интернет магазин',
#  'доверенность отгрузка товар',
#  'дипломный работа взаимодействие семья школа процесс физический воспитание младший школьник скачать бесплатно регистрация',
#  'алюминий моторный закуп переработка цветной чёрный металл',
#  'видео радоловка альбом видео разный разный видео',
#  '',
#  'б',
#  '',
#  'откуда браться плохой отец',
#  '',
#  'склеить пвх плёнка домашний условие простой способ склеивание полиэтиленовый плёнка нужно помнить химия физика',
#  'юля россия южа сайт знакомство',
#  'мерный моргенштерн скачать бесплатно музыка мерный моргенштерн песня песня онлайн',
#  'оплата заказ заказ',
#  'мир',
#  'торрент порно скачать скачать ролик развратный красотуля',
#  'определение июль г дело судакт ру',
#  'канал смотреть онлайн прямой эфир',
#  'инвестиция заработок',
#  'вакансия директор развитие москва работа смартплеер',
#  'двухлетний девочка умереть больница белгородский область постановка капел',
#  'алюминиевый трехсекционная лестница сибртех х ступень пермь купить цена отзыв характеристика фото инструкция',
#  'столото квитанция',
#  'работа сфера складской хозяйство ростов дон',
#  'монте кристо ангел виться ангел суетиться бес цвести сирень слово песня',
#  'война квадрат видео взять самолёт игра битва квадрат смотреть онлайн видео бесплатно видеохостинг',
#  'насколько точно определять расстояние',
#  'фотосессия муж',
#  'интерферон альфа цена наличие аптека купить интерферон альфа украина',
#  'концертный зал колизей санкт петербург афиша мероприятие цена билет',
#  'журавлёв вера анатолиевич репетитор ярославль',
#  'сексапильный тёлочка пососать дать вставить ухажёр',
#  'скачать песня бесплатно',
#  'монолитный поликарбонат ярославль компания полимакс ярославль',
#  'карта сайт',
#  'альбом это александр год россия зеленоград сеть знакомство мамба',
#  'лифтинг клиника идеал специальный цена хороший специалист москва',
#  'город подошва тыс результат поиск',
#  'маленький сиська страница',
#  'й',
#  'хлебопечка цена грн купить сокаль',
#  'юрченко болгария менее нормальный результат футбол владлен юрч',
#  'структура слово основа слово английский любовь',
#  'поезд маршрут ерментау астана',
#  'сериал дорога пустота сезон серия смотреть онлайн бесплатно хороший',
#  'аксиома биржевой спекулянт аудиокнига слушать онлайн',
#  'сумма разность число киберфорум',
#  'гараж час идея малое бизнес',
#  'профиль пользователь рейтинг отель гостиница мир',
#  'изготовление сувенир сувенирный продукция логотип заказ',
#  '',
#  'видео',
#  'лесоустройство учебный пособие',
#  'вч транзистор полевой транзистор полупроводник импортный эль',
#  'индивидуальный предприниматель приймак борис александрович ип реквизит компания октябрьский башкортостан республика россия узн',
#  '',
#  'восстановить пароль контакт номер телефон почта восстановить страница вк иметь доступ телефон знать п',
#  '',
#  'детский сад теремок антитеррористический безопасность',
#  'весёлый ребята октябрёнок текст поиск',
#  'школьный коллекция',
#  'книга оливия гейтс бесплатно скачать читать онлайн регистрация всё',
#  'сколько год алла пугачёв найти поиск',
#  'отзыв инструмент машина заточка сверло нож диолд мзс мнение покупатель интернет магазин диолд',
#  'системный требование отзыв оценка цена скидка гайда прохождение похожий игра',
#  'музыкальный открытка день рождение',
#  'картофель варить жареный деревенски рецепт фото',
#  'доска сосна влажность сухой купить нижний новгород выгодный цена',
#  'новый коррекция запись пользователь мария сообщество ребено',
#  'холодильник тыс результат поиск',
#  'актогай аягоз расписание поезд ктж год',
#  'принцип предпринимательство интернет бизнес экономика',
#  'надземный пешеходный переход глобус леруа мерлен дорога транспорт информационно развлекательный портал',
#  '',
#  'запчасть грузовой легковой автомобиль оборудование сто',
#  'поиск товар запрос контроллер ключ',
#  '',
#  'фбу оренбургский цсм оренбург инна огрн официаль',
#  'мандарин шоколад пошаговый рецепт фото вкусно приготовить',
#  'кроссовок кожаный молния бахрома чёрный',
#  'чёрный кошка ростов дон ростовский обл россия мир',
#  'рахымжан жакайым попурри тойский',
#  '',
#  'секс порно ролик волосатый киска ххх видео онлайн',
#  '',
#  'готовый курсовой работа тема разработка интернет система заказ доставка пицца купить цена руб',
#  'нож финский кованый ст хв литьё рукоять ценный порода дерево',
#  'шапкин павел александрович ип г москва инна реквизит юридический адрес кпп огрн схема проезд сайт телефон узнать',
#  'г',
#  'просмотр увеличить изображение загрузить фото',
#  'игра записка фантастический лес играть онлайн бесплатно',
#  'почтовый индекс улица олег кошевой г владикавказ республика северный осетия',
#  '',
#  'управлять компания жилищный коммунальный сервис чапаевск адрес телефон',
#  'анкета пользователь светлана логинов год лянтор',
#  'результат поиск',
#  'книга логопедический занятие детский сад второй младший группа жанр ме',
#  'шасси прошивка',
#  'глава право користування чужой земельный далее лянкою льськогосподарських потреба цив льний кодекс укра',
#  'читать книга спасатель автор конторович александр онлайн страница сайт',
#  'зелёный оттенок',
#  'работа поиск работа минск беларусь',
#  'сирек казахско русский словарь',
#  'лариса год россия москва фото познакомиться парень проведение совместный досуг трулоло знакомство',
#  'теплоход александр свирский',
#  'поиск дубликат сигарета оптом',
#  'вика год рыба белый анкета знакомство сайт',
#  'время приключение сообщество фанат картинка гифки прикольный комикс интересный статья тема',
#  'карта юбилейный год подробный район название улица номер дом',
#  'бахтеев однофамилец',
#  'порно вк видео',
#  'уплотнитель капот',
#  'магазин правильный мысль',
#  'прилететь ссср год получить секретный беспилотник сша оружие россия информационный агентство',
#  'результат поиск',
#  'гитлер сталин брат близници правда демократический враки верить',
#  'администрация кго почта',
#  'инженер электрик',
#  'ральф смотреть онлайн киного качество бесплатно',
#  '',
#  '',
#  'выездной семинар ицхак адизеса ноябрь баку азербайджан',
#  'страница услуга уральск объявление оказание платный услуга',
#  'подключаться громкий связь видеовызове поиск',
#  'ракетка бадминтон купить ракетка бадминтон самара низкий цена экипировочный центр',
#  'ташкентский область ташкент результат поиск сайт знакомство',
#  'бум весна осень зима страница',
#  'запчасть грузовой легковой автомобиль оборудование сто',
#  'ошибка фнс россия',
#  'налоговый кодекс рк статья исчисление амортизационный отчисление',
#  'танец минус весна текст песня слово',
#  'кассета велосипед звезда аксессуар запчасть велосипед',
#  '',
#  'иос отопление вентиляция кондиционирование воздух тепловой сеть облако',
#  'костюм термо век пума',
#  'поиск человек снежана варычева',
#  'поездка попутчик дать водитель',
#  'этажный дом м аренда длительный срок ярославль промзона улица декабрист объявление',
#  'почему неуверенность являться главный причина мешать найти любовь женский журнал всё мода шоу бизнес отношение кр',
#  'скачать песня бесплатно музыкальный подборка альбом исполнитель слушать музыка онлайн заяц',
#  '',
#  'красивый русский секс камшотом ягодица девушка',
#  'порно латинки страница',
#  'светлана кинберг',
#  'вспомнить весь поимённо',
#  'скачать смотреть онлайн',
#  'хатиора название описание фото вид растение гермин солеросовая отличие кактус рипсалиса также ядовитый комн',
#  'объединение кондитер отзыв млн результат поиск',
#  'водопад чистка защита автор',
#  'читать манга красный кровь красный наследие глава русский онлайн',
#  'гомельский область мошенник выманить предприниматель товар тыс рубль',
#  'валерий википедия тыс результат поиск',
#  'список литература болезнь почка',
#  'далее билет октябрь москва липецк выбор поезд',
#  'сбежать баку скачать клип бесплатно смотреть онлайн',
#  'тройчатый харьков расписание электричка пригородный поезд',
#  'толстовка женщина россия',
#  'идти загрузка',
#  'авиабилет казань астрахань рубль',
#  'единый дежурный диспетчерская служба тольятти хороший страна волжский коммуна',
#  'песня караоке жанр несчастный любовь бесплатный караоке караопа ру',
#  'мокап рисунок',
#  'игра драгоценный камень взрыв играть онлайн бесплатно',
#  'новый плащ подкладе купить санкт петербург цена руб продать июль верхний одежда',
#  'видео ктз русый видео',
#  'автомобиль запчасть новосибирск',
#  'тело телефон приволжский электрический сеть оп ао саратовэнерго поволжье номер',
#  'ракушка барахолка',
#  'электронный регистратура самарский область купаева н б',
#  'тюлька треск тыс результат поиск',
#  'купить шоколадный пончик г кредит кокшетау магазин',
#  'подтвердить дизайн',
#  'елена',
#  'вчера великий новгород обсудить достижение слабый место молодёжный политика',
#  '',
#  'фильм сквозь туман скачать торрент хороший качество бесплатно',
#  'русский скачать торрент игра бесплатно регистрация',
#  'бытсервис оао апатит ул октябрьский далее',
#  'шагать москва который большой иван ургант пронзительно попрощаться георгий данелия рамблер новость',
#  '',
#  'фотография депрессия',
#  'импорт компьютерный комплектующие',
#  'пять золотой пять делиться делиться попробовать разделить пять получаться получать цитата афоризм',
#  'стол заказ страница',
#  'телефон газовый служба тобольск',
#  'запечь шампиньон сыр сметана',
#  '',
#  'адрес организация санкт петербург подать жалоба коммунальный служба',
#  'пг п нв переключатель галетный интернет магазин',
#  'дверной полотно глухой каролина х мм красный дерево радиал цена',
#  'личный кабинет',
#  'мода деньга бесконечный ресурс игра скачать бесплатно крутой ролевый файтинг',
#  'мерседес класс год ангарск цвет чёрный стоимость тыс р хэтчбек акпп пробег тыс км',
#  'евгений маргулис таня дура',
#  'видео',
#  'дальномер всё объявление продажа',
#  'принцесса спорт предмет',
#  '',
#  '',
#  'просмотр увеличить картинка загрузить фото картинка изображение',
#  'чемпионат мир собака пройти всемирный выставка',
#  'секс монстр часть порно комикс',
#  'купить грузовик камаз цена грузовик тонна фото',
#  'тетрадь упражнение русский язык класс галина мисаренко рецензия отзы',
#  'гдз математика класс мишакина задание стр',
#  'газовый горелка цена рубль отзыв фото выбор параметр каталог модель интернет магазин всеинструменты ру',
#  'лиса ставрополь',
#  'поле тетрадь чертить вручную',
#  'скачать песня зарядка ребёнок танец маленький утёнок бесплатно слушать онлайн',
#  '',
#  'оценка результат велоэргометрии норма показатель велоэргометрии',
#  'м москва фоторесурсы',
#  'рождественский коллекция макияж г л этуаль чернокнижница',
#  'спасибо покупка',
#  'каждый раунд игрок выдаваться деньга',
#  'купить электропривод неликвид',
#  '',
#  'тест страница лайфхакер',
#  'скидка интернет магазин',
#  'фен характеристика технический описание интернет магазин м видео москва',
#  'скачать бесплатно',
#  'коттедж дом участок',
#  'погода углицком час подробный прогноз погода чесменский район челябинский область россия',
#  'коса рыбий хвост заплести',
#  'звезда молодежки анна михайловский нежно поздравить брат совершеннолетие летидор',
#  'шаль палантин накидка запись рубрика шаль палантин накидка дневник нат',
#  'текст песня тирольский йодль звук музыка перевод слово песня видео клип',
#  'юрий яков калининград',
#  'салон красота красотка автовской улица санкт петербург официальный сайт',
#  'скин актив крем мл цена москва рубль',
#  'петропавловск камчатский всё вопрос перевозка автомобиль регион решать автомат седан бу',
#  'дмц научить жить текст песня',
#  'палатка навес купить доставка великобритания',
#  'купить складный велосипед феникс велосипед дюймовый складный велосипед взрослый скорость переменный скорость мужской женски',
#  '',
#  'поиск',
#  'спрей грунт серый мл автоцвет',
#  'окно пластиковый х камерный глухой размер мм тамбов',
#  'подполковник устюгов млн результат поиск',
#  'елена зеленская последний новость тег елена зеленская',
#  'купон руб оплата оправа',
#  'парень элина свитолиной фото новый причёска гаэля монфиса сегодня',
#  'скачать альбом сборник песня бесплатно',
#  'поиск почта',
#  'снять квартира слуцк длительный срок посредник сдать квартира слуцк длительный срок',
#  'продажа авто мицубиси монтеро спорт омск продажа собственник омский область руль левый л вд цена тысяча руб дилер бензин',
#  'результат поиск сырок александров',
#  'резаный огурец мариновать зима пошаговый рецепт фото',
#  '',
#  'скачать труба стальной электросварной оцинковать повышенный коррозионный стойкость технический условие',
#  'рамочка счастливый обсуждение российский сервис онлайн дн',
#  'скачивание зацепить минус',
#  'презентация аз л п н нен мара ак л ор ы туралы',
#  'канцелярский принадлежность интернет магазин палитра',
#  'имя часть первый',
#  'список поставщик продукт питание',
#  'международный фотоконкурс',
#  '',
#  'видео',
#  'женский кроссовок белые интернет магазин',
#  'отзыв покупатель',
#  'барулин почта',
#  'ботинок звёздный война демисезонный детский обувь владивосток',
#  'постановление декабрь г дело судакт ру',
#  'основа шахтный аэромеханика студопедия',
#  'инструкция порядок совершение нотариальный действие нотариус млн результат поиск',
#  'торрент порно скачать скачать порно хентайная эротический',
#  '',
#  'федеральный поставщик запчасть строительный оборудование бензо электро инструмент садовый техника клинингового уборочный оборудование',
#  'виктория гетто волк стая страница читать',
#  'цементный стружечный плита строительство частный дом статья интернет магазин материк',
#  'аренда автобетононасоса витебск сравнить цена заказать услуга маркетплейсе',
#  'скачать песня джемма халид',
#  'дизайн детский комната поиск',
#  'цена система руб москва купить бесплатный доставка вытяжка система прочить',
#  '',
#  'видео лариса м видео смотреть онлайн мир',
#  'шаровой опора автозапчасть нерюнгри',
#  'голый дамочка садиться волосатый пилотка лицо партнёр пол',
#  '',
#  'муж сестра порно видео',
#  'парка екатеринбург',
#  'платье брюки акцент талия носить осень мода стиль',
#  'салон одежда обувь самара куйбышев',
#  'сериал родитель сезон серия смотреть онлайн видео сериал фитнес сезон хороший качество видеохостинг',
#  'вакансия машинист насосный установка комсомольск амур работа компания амур золото работа вахтовый метод',
#  'приложение консультантплюс',
#  'дом новость слух саша гозиас привезти проект свой мать маленький дочь',
#  'поздравление год подруга',
#  'выжить любой цена замбия смотреть онлайн видео хороший качество видеохостинг',
#  'видео домашний мамочка зрелый дама секс игрушка бабушка',
#  '',
#  'инструкция тыс результат поиск',
#  'победитель всероссийский конкурс молодой учитель стать педагог мо телеканал',
#  'спасибо покупка',
#  'перемещение прямолинейный равноускоренный движение',
#  'футболист брено филип карточка игрок футбольный онлайн менеджер живить футбол',
#  'шлифовальный работа самара',
#  'видеокарта гб тыс результат поиск',
#  'наполеон хилл скачать аудиокнига думать богатеть скачать бесплатно читать онлайн слушать аудиокнига',
#  'дом адрес г подольск ул долгий',
#  'мир',
#  'скачать песня',
#  'тестовый задание английский язык класс',
#  'агентство реклама печать полиграфия ксерокопия ламинирование цифровой печать сувенирный продукция нанесение логотип разный продукция наружный реклама вывеска стенд',
#  'грибочек лесочек страница уаз патриот сибирь',
#  'изучать спрос панты марал',
#  'галерея изображение бу чр спортивный школа олимпийский резерв хк сокол',
#  'кед высокий',
#  'рецензия фильм рэмбо последний кровь фильм тыс результат поиск',
#  'есенин',
#  'актуальность профилактика злостный нарушение установленный порядок отбывание',
#  'внеклассный мероприятие тема сущность самовоспитание результат',
#  'ловушка изобильный мышление',
#  'новокузнецк фото страница',
#  'решебник дидактический материал русский язык класс ульянов поиск',
#  'результат поиск школа дурак',
#  'фотография альбом пользователь',
#  'анна назарьева эротичекие фото актёр советский российский кино эротичес',
#  'ф р дэвид скачать бесплатно ф р дэвид',
#  'фильм ангел демон ангел демон актёр отзыв',
#  'газовый горелка свой рука вариант домашний дело газовый горелка свой рука',
#  'цсп отделение шахматы псков адрес улица свердлов телефон сайт реж',
#  'анатомия страсть',
#  'отклик соискатель',
#  'юбилей мужчина',
#  'методический указание выполнение работа дисциплина эффективный поведение н',
#  'екатерина коб голый тыс результат поиск',
#  'результат поиск',
#  'считыватель карта',
#  'неустойка ст гк рф формула расчёт неустойка залог внесудебный реализация гарантия задаток др способ обеспечение казахстанский',
#  'слушать русский радио россия г москва поп музыка',
#  'скорость свет вакуум невозможность распространение информация быстрый',
#  'класс презентация история каталог файл сайт учитель история обществознание',
#  '',
#  'мбуз городской поликлиника г ростов дон инна огрн',
#  '',
#  'заводиться замена топливный фильтр страница',
#  'секрет красота уход',
#  'восточный европейский овчарка фото восточный европейский овчарка общий вид восточник тип конституция рост восточный европейский поведени',
#  'дешёвый авиабилет онлайн',
#  'сборная союз час женатый слушать скачать бесплатно',
#  'домик питомец',
#  'победа локомотив позволить россия оторваться португалия таблица коэффициент уефа новость еврокубков футбол спорт',
#  'надувной лодка лоцман м рс цена руб купить минск',
#  'вощёный парусиновый сумка',
#  'радуга фиалка рм роса изумруд н скорнякова',
#  'писать онлайн тешиться ванная',
#  'продукция товар услуга компания фактор спецэлектроника',
#  'концепция жизненный мир э гуссерля герменевтический проблема тема научный статья философия читать бесплатно текст научно',
#  'мафик кент',
#  'запрос свитер вырез найти результат интернет магазин',
#  'проект безопасный качественный автомобильный дорога регион отремонтировать трасса новость пермь',
#  'сиренко аркадий василиевич это сиренко аркадий василиевич',
#  'положение порядок приём педагогический работник работа конкурсный основа муниципальный бюджетный учреждение дополнительный образование спортивный школа город ливны',
#  'королевский ватрушка рецепт вкусный выпечка',
#  'резинотехнический автокомпоненты премиум класс сайлентблок попереч',
#  'шить кожа набор изготовление кошелёк стандарт готовый набор',
#  'смартфон',
#  'сдавать комн квартира пр королева собственник сжм северный жилой массив ростов дон фото детский сад неагент',
#  'просмотр резюме',
#  'врип глава раменский район николай воробьёв обсудить житель благоустройство пруд главный новость подмосковье',
#  '',
#  'квартира вторичный рынок купить спб продажа квартира вторичке',
#  'смотреть клетка сезон бесплатно онлайн',
#  '',
#  'тапочки носка пинетка запись рубрика тапочки носка пинетка дневник нина',
#  'мир',
#  'б ограф нум рапас',
#  'дэвид вебер восстание читать онлайн',
#  'фильм высоцкий спасибо живой высоцкий смотреть онлайн бесплатно российский фильм сериал кино театр ру',
#  'книга записка хвостатый звезда читать онлайн евгений чепенко страница',
#  'лоадеры укра н пора вняти ц придбати споживч товари маркетплейс',
#  'снежинка бумага любовь париж',
#  'отзыв личный опыт',
#  '',
#  'архангельский опытный водорослевый комбинат',
#  'вольга микула селянинович гипербола эпитет повтор приве',
#  'биквадратный уравнение алгоритм решение пример',
#  'кнопочка москва год фото страница',
#  'юрист защита право потребитель москва бесплатный консультация юрист защита право потребитель',
#  'скачать торрент ролик',
#  'мультфильм онлайн смотреть бесплатно хороший мультик хороший качество',
#  'фото виторгана нинидзе греция экспресс газета',
#  '',
#  'точно скачать песня бесплатно',
#  'отчёт матч',
#  'краснодарский край результат поиск страница',
#  'сенсор датчик автоматизация здание помещение умный дом страница',
#  'ботинок купить руб интернет магазин',
#  'конструктор паровозик астротойз',
#  'макрон хотеть создать альянс доверие германия избежание распад ес европа новость день',
#  'постановление октябрь г дело судакт ру',
#  '',
#  '',
#  '',
#  'сие таррэн феррис аканехиде',
#  'декасан состав препарат помогать стомалогории бронхит ангина применять беременность ребёнок цена аналог',
#  'дорога попутчик хлопоты',
#  'чёрный босоножка блочный каблук',
#  'форум кукла',
#  'грамотно расставить мебель маленький кухня использовать всё пространство',
#  'вакансия студент город санкт петербург работа гибкий график',
#  'полный вагин сперма онлайн смотреть бесплатно порно видео онлайн',
#  'цена руб купить москва',
#  'отзыв сбербанк россия двойной списание средство мобильный банк банк ру',
#  'телок питер знакомство новый друг сниматься крутой домашний порн',
#  'русский язык класс ладыженская м баранов ч номер',
#  'иерусалимский королевство всё монархия мир',
#  'отучить лайк поедать трепать битый дичь зверёк',
#  'сайт знакомство',
#  'россия санкт петербург м лесной',
#  'сервис доступный',
#  'термо комбинезон мальчик французский грн одежда мальчик киев',
#  'редактировать товар личный кабинет',
#  'коттедж дом участок',
#  'порно видео онлайн мина',
#  'стих ребёнок зимовать животное',
#  'уайат сенак разрулит сезон серия смотреть онлайн беспла',
#  'тюменский дизайнер ален дубровин получить гран москва новость тюмень',
#  'кот морда вниз',
#  'администратор отель',
#  'ооо группа компания михайлов партнёр москва инна огрн',
#  'сергей скрипаль контингент книга афган читать онлайн',
#  '',
#  '',
#  'кислота фармакология',
#  'читать манга боевой континент страна душа глава русский онлайн',
#  'продаваться ссангйонг рекстон год томск собственник владеть год литр бензин акпп',
#  'запчасть грузовой легковой автомобиль оборудование сто',
#  'нордрута пододеяльник наволочка серый синий',
#  'манга онлайн',
#  'продать батарея грн отопление харьков',
#  'автозапчасть город дюссельдорф германия каталог магазин автозапчастей адрес телефон время работа сайт',
#  'вакансия инженер видеонаблюдение серов работа компания угмк холдинг полный рабочий день',
#  'секс выпускной вечер',
#  'скачать порно длинноволосый красотка телефон',
#  'мег монстр глубина скачать торрент файл бесплатно',
#  'решить упр урок гдз кузовлев класс перевод задание',
#  'анатоль год лев плещеницы анкета знакомство сайт',
#  'крахмал загуститель заменитель полезный очень выглядеть',
#  'сдать ю квартира июнь грн долгосрочный аренда квартира комната ильичевск',
#  'серия сезон мультсериал гриффины озвучке студия игра свидание смотреть гриффины онлайн качество',
#  'далее',
#  '',
#  'расстояние ростов дон феодосия км маршрут',
#  '',
#  'тюнинг казань сравнить цена купить потребительский товар маркетплейсе',
#  'сонник картинка скелет сниться картинка скелет видеть сон сонник дом',
#  'рс русский скачать торрент программа бесплатно регистрация',
#  'купальник бикини двухцветном дизайн размер чёрный серый',
#  'обмен скот тг нур султан астана',
#  'скачать бесплатно слушать онлайн видеок',
#  'современный технология обучение музыкальный образование тема научный статья народный образование педагогика читать бесплатно',
#  'человек седан мигрант погибнуть пытаться покинуть гаити',
#  '',
#  'урок класс тема повторение систематизация изучить имя существительное бюджетный общеобразовательный учреждение вышний ольшанский средний общеобразовательный школа',
#  'транспортный налог ветеран боевой совет адвокат юрист',
#  'балаба ша жасында ы балалар арнал ан таныстыру ра жауап',
#  'коттедж новый год загородный отдых',
#  'салат гранатовый',
#  'блондинка больший сиська изнасиловать бдсм игра',
#  'руководство издание четвёртый дополнить переработать',
#  '',
#  '',
#  'проблема сцепление камаз дальнобойщик весь страна объединяться',
#  'барахолка уфа',
#  'отзыв антиперспирант',
#  'профиль пользователь путешествие отдых',
#  'связаться оператор триколор тв тыс результат поиск',
#  'запрашивать страница найти',
#  'профиль пользователь фото сайт',
#  'рс русский скачать торрент игра бесплатно регистрация',
#  '',
#  '',
#  'решение м м сентябрь г дело судакт ру',
#  'тип заинтересоваться дырка опытный женщина выебал диван',
#  'пословица поговорка день неделя',
#  '',
#  'суккулент крассула купер растение владивосток',
#  'сервисный компания буттэк отзыв фото цена телефон адрес сервисный центр москва',
#  'фото кпб поплин византия графит цена руб отдать руб',
#  'доставка продукт дом елизово камчатский край адрес телефон карта проезд',
#  'продаваться автобус автобус комсомольск амур',
#  '',
#  '',
#  '',
#  'саратов дача снт архитектор тыс результат поиск',
#  'детский лагерь огонёк сергиево посад оздоровительный лагерь огонёк детский отдых',
#  'мать смотреть отец трахать красавица дочь',
#  'читать онлайн книга единственный барс бесплатно страница',
#  'купить серебряный браслет беларусь',
#  'сонник смотреть мультфильм присниться сниться смотреть мультфильм сон видеть',
#  'почта',
#  'р ама голый гс дс коса мис ебенка',
#  'программа бесплатный создание сайт движок программный оболочка денвер создание виртуальный хостинг домашний комп',
#  'фёдор бондарчук паулина андреев сыграть свадьба петербург',
#  'автокран ивановец кс р шасси камаз тонна',
#  'смотреть видео онлайн мир',
#  'ружьё хороший мр сайга популярный оружие',
#  'ребёнок ясли обучать инновационный программа российский газета',
#  'знакомство нерюнгри сайт знакомство шура мур',
#  'насос электрический купить москва цена фото отзыв характеристика',
#  'работа поиск работа минск беларусь',
#  'шар латексный',
#  'гласный буква класс конспект презентация урок фгос готовый млн результат поиск',
#  'гифки поиск сайт',
#  'перевод пример предложение',
#  'галерея',
#  'ужас страница',
#  'октябрьский почта',
#  'реклама',
#  'бетостоун быстросохнущий двухкомпонентный полиуретановый грунт эмаль компания рифорн купить город екатеринбург',
#  'поиск работа вакансия зарплата ру',
#  'качать шашка',
#  'фигурка оникс значение древность современность удача',
#  'образ обеспечиваться защита право ребёнок рф защита право ребёнок российский федерация',
#  'золото древний русь черняев ф',
#  'расстановка герой альянс человек воин чешуйчатый охотник неуловимый убийца',
#  'оперативный цифровой типография краснодар',
#  'каждый тыква',
#  'скачать фильм звёздный путь телефон',
#  '',
#  'скачать смотреть онлайн',
#  'поезд самолёт почта',
#  'запчасть блендер деталюга',
#  'система оповещение управление эвакуация статья омега саунд россия',
#  'программа обучение охрана труд',
#  'толкование карта таро разный страница тонкий мир эзотерический форум магия гороскоп гадание заговор приворот сонник астр',
#  'крестный отец пьюзо м купить амиталь доставка',
#  'порадовать жопа аделин ишим район сто',
#  'мир',
#  'подбор шина автомобиль',
#  'сварщик пластмасса еткс',
#  'фото альбом фото группа фото фотография вязание',
#  '',
#  'фото тула',
#  'снабженец экспедитор водитель',
#  'видео михаил кононенко видео смотреть онлайн мир',
#  'эмблема',
#  '',
#  'купить тормозной система томск сравнить цена тормозной система томск',
#  'купить дышать подкладочный ковёр битумный черепица фальцевую кровля натуральный сланец цена москва',
#  'блондинка пышный грудь заниматься секс муж свадьба',
#  'сериал обезьяна сезон смотреть онлайн бесплатно хороший качество',
#  'юленька год россия альметьевск социальный сеть позволять знакомиться общятся человек отправлять смс ещё',
#  'видео молодой русский порно больший дырка мастурбация красотка',
#  'новый современный обезболивание животное',
#  'знакомство рига ольга год бесплатный сайт знакомство датинг ру бесплатный мобильный сайт знакомство серьёзный отношение',
#  '',
#  'шнур далее',
#  'анальный азиатка закатить глаз кончить секс',
#  ...]

# %%
X_test_tokenized = [tokenize(text) for text in X_test]

X_test_lemmatized = [[lemmatize(token) for token in text] for text in X_test_tokenized]

X_test_cleared = [" ".join([token for token in text if token not in stop_words]) for text in X_test_lemmatized]

# %%
X_test_cleared
# Out:
# ['шестой кассационный суд самара начать работа разный здание фото коммерсантъ',
#  'индексация алименты случай производиться каков порядок правило процедура',
#  'женщина империя мех',
#  'небритый волосатый киска порно весь страна национальность онлайн',
#  '',
#  'вакансия мерчендайзер визитный рязань группа компания поиск работа городработ ру',
#  'смартфон чёрный купить интернет магазин фотосклад ру цена отзыв видео обзор',
#  'духов шкаф цена москва',
#  'вакансия аналитик департамент внедрение информационный система платформа',
#  'торрент',
#  'убрать запах выгребной ям',
#  'озаботить старый баба порно фотосессия',
#  'смотреть онлайн н',
#  'ещё видеть айдаприкол',
#  'развивать игрушка весы тюлень солнышко игрушка ребёнок год',
#  'наружный блок',
#  'дочь кадыров признать самый одарённый ученик чечня яплакалъ',
#  '',
#  'рекомендация учёт жёсткость диафрагма стальной профилировать настил покрытие',
#  'продажа год уссурийск отправка регион подробность телефон вап сап акпп л вд дизель дилер',
#  'ерлан тажибаев безгранично влюбить казахский женщина',
#  'кулак рот запись пользователь валерий сообщество здоровье новорождённый категория разный',
#  'триллер смотреть онлайн хороший качество бесплатно страница',
#  'картинка рабочий стол скачать обои страница',
#  'портал очаг купить интернет магазин электрокамин владимир',
#  'найти сумма член ариф прогрессия киберфорум',
#  'кед кроссовок женщина россия',
#  'скачать экшен игра торрент страница',
#  'товар продажа',
#  'тест русский язык',
#  'гостиница москва отзыв отель цена фото номер забронировать гостиница онлайн',
#  'марка машина буква н марка автомобиль буква н',
#  'скачать бесплатно песня',
#  'кронштейн тв наклонно поворотный наличие магазин м видео челябинск',
#  'скачать бесплатно',
#  'яичница ветчина яплакалъ',
#  'доставка',
#  'инвертор барс св',
#  'двадцатилетний телок свободный время красоваться большой жопа прелесть картинка',
#  'работа контролёр великий новгород вакансия',
#  'вакансия продавец консультант одежда поиск работа запрос продавец консул',
#  'бал свой п даком жирный секс бомба анна седокова похвастаться свой роскошный фигура выставить п',
#  'огурец форсаж',
#  'нелли ржевский',
#  'видео',
#  'цена видеоняни купить минск компания интернет магазин',
#  'результат поиск запрос интернет магазин читать город',
#  'вновь кипр октябрь фото фотография оля вейдман',
#  'просмотр картинка аэрофлот',
#  'номер р проверка авто гос номер бесплатно новосибирский область',
#  'признак перфекционист',
#  'бывать прицел карта слово выражение русский язык',
#  'юлия новороссийск год фото страница',
#  'купить детектор газ дом световой звуковой сигнал тревога окись углерод угарный газ копоть угольный печь сирена брикет детектор',
#  'пользователь станок',
#  'фото альбом фото группа фото фотография мужской журнал',
#  'приложение',
#  'функция вид социальный норма',
#  '',
#  'неактивно',
#  'рассказ задница эротика порно смотреть онлайн хороший фильм видео',
#  'мк блок газ бизнес дв регулировка скорость вентилятор отопитель н оао газ мк мк фото цена описа',
#  'отзыв клиент покупатель компания',
#  'архив уход посадка',
#  'мужской зимний куртка стиль топовый качество ц грн купити киев',
#  '',
#  'сидение комплект пит автозапчасть кемерово',
#  'губный помада',
#  'видео',
#  'погода ростовский область россия карта район ростовский область погода',
#  'тверь троллейбус',
#  'красноярск отличный состояние обмен рассмотреть вариант чёрный автомат седан л бу бензин цена тысяча руб',
#  'жареный акула рецепт фото',
#  'толстовочка купить санкт петербург цена руб дата размещение свитер толстовка',
#  'сапог ботинок обувь мальчик',
#  'фигурка характеристика технический описание интернет магазин м видео москва москва',
#  'хорькин борис михаилович тренер санкт петербург',
#  'зимний шина',
#  'поиск глубокий сон каталог торрент профессиональный торрент трекер страница',
#  'мингазова рузиля саетгалиевна уфа тыс результат поиск',
#  'восприятие человек человек носить специальный название',
#  '',
#  '',
#  '',
#  'учебник издательство атамура результат поиск',
#  'наруто смотреть сериал онлайн качать торрент бесплатно',
#  'разница фантастика фентези',
#  'библиотерапия лечение книга книга стр',
#  'правовой основа деятельность союз общественный объединение',
#  'малония гибридный яблоня айвовый гибрид купить ростов плодовый саженец фруктовый дерево привить форма купить растение ростов дон интернет магазин питомник растение хвойный лиственный уличный плодовый де',
#  'вакансия мастер участок волгоград работа ата группа',
#  'узи неделя день блог бэтэшка',
#  'суперотношения любовь семья наладить сберечь илья шабшин',
#  'кормление ягнёнок норма схема кормление таблица',
#  'январь обрезание господний история христианский смысл крестовоздвиженск',
#  '',
#  'видео анал брюнетка красотка смотр',
#  'римма авшалумов убийца неизвестный',
#  'детальный разбор показать конференция это',
#  'задвижка ду ч бр аналог ч бр вода пара эл привод купить бел руб шт минск компания чтуп эймост продажа юр л',
#  '',
#  'ютуб валера желейный медведь новый серия тыс ролик поиск',
#  'ст льц дк код сид ння ст льц супутн вироби частини',
#  'охранник брат',
#  'состязательный рынок концепция состязательный рынок предложить начало х год',
#  'ивановский барахолка кроссовый',
#  'зеркало тумба машенька цена руб каталог выборг',
#  'менять задний поводок дворник лачетти поводок рио всё шевроле фото видео ремонт отзыв',
#  'комнатный квартира м купить руб пермь улица докучаев',
#  'интернет магазин видео настольный игра красноармейский улица отзыв фото каталог товар цена телефон адрес добраться магазин ростов дон',
#  'микаел минасян нынешний власть вместо новый армения выбрать армения фейсбука хороший армянский интернет портал',
#  'женщина год жить единственный партнёр обнаружить вич',
#  'робертс нора смерть иметь лицо электронный библиотека',
#  'знакомство новосибирск мужчина возраст год нгс знакомство',
#  'тётя старательно соснуть молодой племянник',
#  'воздушный вентилятор м час тыс результат поиск',
#  '',
#  'найти запрос мягкий мебель',
#  'купить инфинити ку россия продажа пробег новый цена',
#  'продавать двухкомнатный квартира м москва нао новомосковский внуковский поселение внуково посёлок дск московский писатель посёлок м',
#  'купить бинокль телескоп больший увеличение интернет магазин м видео низкий цена отзыв владелец большой каталог описание ха',
#  'порно видео страница',
#  'скачать смотреть онлайн',
#  'самый отвратительный животное вид который обязательно сказать фуу',
#  'николай александров радиодеталь эхо москва',
#  'скачать книга род сергей александрович давыдов',
#  '',
#  'скачать фильм дрожь земля телефон бесплатно',
#  'диван прямой ульяновск цена столплит страница',
#  'дело сказать задержать украина российский десантник видео',
#  'делать модем гореть мигать лампочка',
#  'купить батут дом улица ставрополь',
#  'саундтрек диктатор скачать слушать онлайн всесаундтреки рф',
#  'кукла коллекционный парочка лена семён наряд клеточка набор шт смотреть микс купить цена руб интернет магазин',
#  'филиал расписание тренировка ано спортивный клуб гимнастика школа ольга капрановой',
#  'бумага высокий печать это бумага высокий печать',
#  'добавление рассылка империя коучей коучинг константин опекун',
#  'потап настя свадьба слушать онлайн бесплатно',
#  'результат оплата',
#  'пятница',
#  'пышка видео',
#  'программа портал',
#  'аренда однокомнатный студия длительный срок екатеринбург ленинский район фото екатеринбург',
#  'результат поиск маслёнка',
#  'скачать свой музлишко красивый сегодня музыка онлайн',
#  '',
#  'читать книга удержать окова сердце страница библиотека книга',
#  'заглушка сайт страница',
#  '',
#  'корпоративный сотовый связь интернет официальный сайт мегафон московский регион',
#  'личный кабинет',
#  'читать манга драгон болл глава русский онлайн',
#  'жк династия ул василий липковского г ковальский страница',
#  'тропа бог вид обсуждение российский сервис онла',
#  'гжатский улица карта гагарин номер дом',
#  'скачать бесплатно назар страна полынь слушать музыка онлайн заяц регистрация',
#  'микро джига головка кр гр купить харьков хороший цена',
#  'дисконт минский гум',
#  'иосиф кобзон мгновение',
#  'з',
#  'сервис контекстный реклама поиск',
#  'тапочки следок спица',
#  'аврора концертный зал санкт петербург клуб аврора санк',
#  'тендер отрасль ремонтный строительный работа орехово зуево найти тендер',
#  'жениться казашка шотландец ваш женщина злой новость казахстан',
#  'купить лексус иса ф б продажа автомобиль пробег россия цена бу авто',
#  '',
#  'год сен смотреть видео онлайн мир',
#  '',
#  '',
#  'диск',
#  'каталог машина разметка дорога компания активатор',
#  'марьиногорская городской библиотека результат поиск',
#  'продавать дом м ул профсоюзный башкортостан респ белорецкий район азикеевский сельсовет буганак село база циан объявление',
#  'проверка датчик личный опыт блог датчик работать',
#  'володимир год украина лев познакомиться девушка возраст год сеть знакомство мамба',
#  'абаканец показать хороший образец боевой машина пожарный',
#  '',
#  '',
#  'ооо гк юстэкс вистино инна огрн телефон реквиз',
#  'девка обожать киска проникать одновременно член',
#  'робкий неуверенный это робкий неуверенный',
#  'объектив характеристика технический описание интернет магазин м видео москва',
#  'карпов вадим юриевич защитник',
#  'фск отказываться лидер газета коммерсантъ',
#  'лариса матвеев видео',
#  'воскресенский угличский мужской монастырь',
#  'ночь рождество спектакль минск',
#  'игровой сервис игра',
#  'мехрнигор рустам скачат секс таджичка душанбе',
#  '',
#  'черничный пирог рецепт фото',
#  'страница кошка старший год',
#  'анатолий могилевский робик чёрный диалог скачать бесплатно песня',
#  'проект росток жизнь беседа первый',
#  'диана дубовик',
#  'визит граница',
#  'брать сандра женский шапка хлопок лён',
#  'примета лиса перебежать дорога примета',
#  'матрас склад наличие новый матрац бесплатный доставка тг мебель спальня алматы',
#  'мощность выбрать лампочка освещённость лк',
#  'михаил боярский моцарт',
#  'радикал фото картинка',
#  'цена монета тенге год стоимость аукцион описание фото',
#  'самый дорога автомобиль цена рейтинг стоимость',
#  'продать швейный машинка сума швейный машина оверлоки ташкент',
#  'курс валюта обменник нурсултан сегодня результат поиск',
#  'двоевластие интернет газета зонакз казахстан',
#  'ах свадьба муслим магомаев скачать бесплатно ах свадьба муслим маг',
#  'сайт крафтящих значок форум',
#  'авто опель астр год барнаул автомобиль отс седан бензин серебристый акпп литр',
#  'внешний импульс прогрессировать сложный система',
#  'переспать двоюродный брат анал новый жёсткий порн видео',
#  'экскаватор улаанбаатар далее нэг й зарууд худалдаж авна зара',
#  'ростов бавария ноябрь обзор матч чемпионат',
#  'порно',
#  '',
#  'подбор запчасть код поиск запчасть вино код онлайн заказать автоз',
#  'интернет провайдер запорожский приозерский район ленинградский область подключить интернет адрес дом запорожский приозерс',
#  'вакансия комплектовщик склад мегион работа компания работа вахтовый метод',
#  'взаимосвязь постоянный переменный капиталь',
#  'эльза альметьевск',
#  'учитель медленно оттрахал студентка юбка курение территория университет смотреть скачать порно бесплатно',
#  'работа нижний тагил сантехник',
#  'объявление продажа комнатный квартира новосибирск ул гоголь нгс жилой',
#  'фотография отель мирабель фото анапа',
#  'практикум решение задача тема металл',
#  'искать работа личный авто транспорт логистика нур султан астана',
#  'спальный мешок купить москва цена руб дата размещение туризм отдых природа',
#  '',
#  '',
#  'снять квартира рабочий посёлок навле навлинский р н посредник аренда квартира рабочий посёлок навле навлинский р н недорого хозяин агентство',
#  '',
#  'алексей михайличенко новость биография фото публикация',
#  'шуточный фальшивый деньга доллар штука деньга выкуп невеста продажа цена алматы сувенирный деньга интернет магазин полезный товар',
#  'рифма слово трещать',
#  'архив дисней',
#  'карта сайт',
#  'коломна тепло сервис',
#  'правило русский язык класс комплект карточка',
#  'акция качественный набор инструмент головка отвёртка грн ручной инструмент винница',
#  '',
#  'песок доставка гродно район гродно',
#  'сергей савельев рига латвия год мир',
#  'тест самоконтроль введение психолого педагогический деятельность учебн',
#  'подборка тендер почта',
#  'обои тема американский модель актриса',
#  'ь',
#  'погода горка завтра прогноз погода завтра краснопольский район могилёвский область беларусь',
#  'девственник гэблдон диана читать онлайн',
#  '',
#  'слуга дьявол скупщик людской душа история продажа душа мир тайна',
#  'сумеречный дева амнезия смотреть онлайн бесплатно красвью',
#  '',
#  'результат поиск',
#  'профиль ёжкин кот персональный страница пользователь',
#  'оксана год россия курск познакомиться парень познакомиться парень це',
#  'отличаться антуриум спатифиллума дача сад огород комнатный растение',
#  'почему скрипеть кровать это делать',
#  'объектив гелиос легендарный закрутить бок супермакро просто отличн',
#  'репетитор корейский язык грозный ассоциация репетитор грозный',
#  '',
#  'застрелить квартира воронежец оказаться знакомый обвинять сутенёрство адвокат риа воронеж',
#  'людмила год марьин горка фотография сайт знакомство',
#  'фильм похожий сериал стандарт красота сезон скачать смотреть онлайн',
#  'охота смотреть онлайн качество отзыв кадр фильм актёр кино',
#  '',
#  'гленн клоуз фотография голливудский актриса кино театр ру',
#  'саженец голубика высокорослый цена руб купить берёза',
#  'история фамилия свидрак значение происхождение фамилия свидрак',
#  'коллекция монета',
#  'вакансия специалист охрана труд техника безопасность улан удэ работа',
#  'вакансия фотограф автомобиль москва работа фотограф автомобиль',
#  'создатель острый козырёк снять харди минь сериал кино',
#  'рамблер касса',
#  '',
#  'мужской кроссовок',
#  'тайна муж',
#  'купить умный колонка яндекс станция интернет магазин ситилинк цена умный колонка яндекс станция тверь',
#  'столото квитанция',
#  'купить рено логан донецк продажа пробег новый цена',
#  'купить грузовик маз грузоподъёмность кг барнаул цена грузовик тонна фото',
#  'бижутерия брошь страница',
#  'скачать модель бесплатно страница',
#  'ошибка страница найти',
#  'купить круг отрезной абразивный металл луг х х мм луг абразив ярославль цена отзыв характеристика доставка гаран',
#  'товар услуга компания спутниковый комплект триколор нтв телекарта мтс',
#  'фото альбом портфолио свадьба константин ягодзинский',
#  'порно скачать смотреть бесплатно',
#  'результат поиск мм кг флюс припой',
#  'резюме сварщик канск иван концеренко год обновить',
#  '',
#  'контент план реализация тв контент менеджер удалённый фриланс',
#  'порно фото смотреть бесплатно',
#  'знакомство минск анна год страна встреча сайт знакомство серьёзный отношение общение',
#  '',
#  'тоо талдыкорган сайт флагма казахстан',
#  'детский блуза декоративный воротник голубой цвет купить руб интернет магазин цум арт',
#  'педагогика конспект лекция лекция понятие методология педагогический наука шарохина',
#  'ь з',
#  'фото альбом фото фото фотография александр шанцев',
#  'виктор год город москва россия айта знакомство',
#  'пойти',
#  '',
#  'конструктор предложить заменить ан однодвигательным моноплан военный обозрение',
#  '',
#  'скачать ева кэссиди слушать песня онлайн',
#  'имбирь сахара польза рецепт',
#  'готовый перевод переродиться свиногерцога сказать любить глава жить хотеть',
#  '',
#  'знак',
#  'компьютерный гарнитур интернет магазин гиганти петербург',
#  'объявление новостройка стадия котлован пятигорск жилой комплекс жк этап котлован пятигорск циан',
#  'клава кока тихий',
#  'нок нод',
#  'парень искать девушка томский область парабель результат поиск сеть знакомство мамба',
#  'риелтор мишин елена вениаминович гдеэтотдом ру',
#  'псковский медицинский училище колледж псков сайт всеколледжи рф',
#  'читать книга русский свой бросать автор большак валерий онлайн страница сайт',
#  'алексей мерчин год мир',
#  'компланарный вектор презентация геометрия',
#  'результат скрининг запись пользователь сообщество клуб беременная категория анализ',
#  'магазин мир инструмент ооо дровосек чебоксары',
#  'фото штора капля красота',
#  'натуральный обезводить ломтик манго марка доить кхам',
#  '',
#  'центральный улица карта кварцитного посёлок карелия номер дом',
#  'ц цзь ь ь',
#  'статус смысл любовь страница',
#  'импровизация вечеринка выпуск фрагмент импровизация смотреть онлайн видео бесплатно видеохостинг',
#  'тетрадь лист клетка котёнок белизна картонный обложка микс купить цена руб интернет магазин',
#  'зимний комбинезон купить руб москва объявление',
#  '',
#  'глава вак прокомментировать предложение бессрочный лишение учёный степень риа новость',
#  'интерн бесплатный торрент скачать бесплатно',
#  'поиск картридж',
#  'купить серьга золотой проба камень интернет магазин московский ювелирный завод',
#  'кейптаун смотреть онлайн сезон',
#  'кольцо чёрный жемчуг классика п чёрный золотой чёрный золотой',
#  'приём который помочь вырваться замкнутый круг начать жить',
#  'найти судебный решение совет адвокат юрист',
#  'поэнг подушка сидение табурет нога шифтебу коричневый',
#  'дорога попутчик хлопоты',
#  '',
#  '',
#  '',
#  'продажа дом м аргаяшский ул челябинск челябинский область база циан объявление',
#  'новый страница смотреть бесплатный порно видео',
#  'презентация тема учиться читать тренажёр чтение учитель начальный класс',
#  'город качканар фото',
#  'чужой звезда каменеть алекс страница чтение книга бесплатно',
#  'относительный удлинение всё формула',
#  'страница форум антивирус софт касперский',
#  'василий гайдук слуцк минский обл беларусь год мир',
#  'метод подсказка выбор твердотопливный котёл',
#  'екатеринбург новосибирск ноябрь туда ноябрь обратно',
#  'куртка трекинговая грн туризм вано франк вськ',
#  'гильермо дель торо штамм комикс комикс мир фантастика фэнтези',
#  'результат поиск',
#  'плитка тротуарный барнаул компания ооо строй',
#  'новость сообщение официальный группа вконтакте магазин вольный стиль тц спорт хит одежда обувь москва',
#  'оттенок золотистый каштановый хороший краска волос',
#  'слесарить ремонт автомобиль аппаратчик вакансия компания автоколонна',
#  'биография малка лоренц софья кочетовой',
#  '',
#  'бальзам хамелеон губа оттеночный прикольный',
#  'специалист оплата нормирование труд присвоение квалификация специалист персонал ч',
#  'картинка фантазия рабочий стол скачать обои фэнтези страница',
#  'минь велотренажёр велотренажёр велоэргометр домашний занятие спортдоставка екатеринбург',
#  'решение выпуск страница математика самостоятельный контрольный рабо',
#  'входной дверь сенатор венге',
#  'выписка билет',
#  'объявление снять квартира недорого пятигорск дешёвый жильё циан',
#  'предполагать дочь путин катерина тихонов развестись муж новостной портал',
#  'установление причастность тлеть табачный изделие тти возникновение пожар',
#  '',
#  'сексапильный молодуха широко раскрыть свой волосатый бутон порно фото секс',
#  'пальто юрс красный модель белорусский трикотаж интернет магазин швейный традиция',
#  'кроссовок мужской кожа чёрный зимний москва',
#  'маска хамелеон млн результат поиск',
#  'натуральный вкус малина мкг жевательный таблетка',
#  'шарм эль шейх египет описание фотогалерея тур отель',
#  'архив допотопный технология жёлтый роза',
#  'константин муравей нейтральный мир страница читать',
#  'роскачество предложить приравнять вино сельскохозяйственный продукт',
#  '',
#  'сениченко ольга сергеевич страница',
#  'гардеробный ларвидж',
#  'скачать песня рассказать каков бросить самый хороший любимый предать засыпать вспоминать прошлое свой сердце хранить вселенная рассказать каков девочка рассказать каков бросить бесплатно слушать онлайн',
#  'правильно писаться слово туманный ударение слово туманный',
#  '',
#  'кейс уберизировать дальнобойщик выйти оборот сотня миллион',
#  'купить женский обувь больший размер купить обувь полный нога купить колготки большой размер страница',
#  'голый азиатка супер сексуальный тайка делать фото эротика пляж',
#  'семейный история часть вера хороший коллекция порно рассказ',
#  '',
#  'тюнинг отзыв личный опыт',
#  'пайка металл отличие сварка особенность подготовка поверхность',
#  'сородич журавль сканворд буква тыс результат поиск',
#  'нигер нефть газ уголь',
#  '',
#  'поиск табель почта',
#  'деталь фото',
#  'карамельный булочка л н',
#  'урок стандартный плагин сообщество разработчик игра',
#  'зрелый подруга решить полизать киска работать самотыками',
#  'ь ь ц ь ц ь',
#  'маршрут анапа село витязево расстояние карта',
#  'бу ина нефрит чёрный мм круглый каменный бусина нефрит диаметр бисер бусина творчество рукоделие',
#  'продать участок ленинградский область база циан объявление',
#  'бизнес план выращивание фазан хороший бизнес идея',
#  'такси ижевск алнашей предзаказ россия кросстакси',
#  'порно групповуха смотреть онлайн порно мама ххх бесплатно качество страница',
#  'чп ташкент сайт флагма узбекистан',
#  'сериал монтекристо серия смотреть онлайн',
#  'блузка женщина россия',
#  'л харабали астраханский обл россия мир',
#  'объявление таджикистан',
#  'часто задавать вопрос возврат деньга телефон',
#  'бесплатный скрипт хайпов метод заработок вложение заработок интернет страница',
#  '',
#  'скачать фильм скелет железный остров бесплатно скачать фильм бесплатно регистрация смс отличный качество',
#  'порно фильм результат поиск',
#  'светлана нарчук',
#  'журнал г ростов дон отзыв',
#  'гостиница чувашия звезда чебоксары',
#  'анютик год брест фотография сайт знакомство',
#  'яуехал год россия анапа фото познакомиться парень познакомиться парень цель знакомство дружба общение любовь романтический отноше',
#  'смотреть онлайн мультсериал свинка пеппа сезон реальный новый серия',
#  'форма моделирование',
#  'читать онлайн лисиный александр магиня электронный библиотека',
#  'секс трио жена сосед',
#  '',
#  'поиск рюкзак страница',
#  'лерканидипин инструкция применение лекарство аналог отзыв',
#  'дмитрий дёмин маркетинг привлечь удержать клиент скачать литрес',
#  'тепловизионный обследование цена руб услуга заказать могилёв',
#  'социально экономический развитие россия студопедия',
#  'ц н б ц й',
#  'тыс результат поиск',
#  'ландыш прекрасный сургут фото страница',
#  'алексей',
#  'дневник асоциальный сеть',
#  'контакт',
#  'иллюстрация русский язык класс проверочный контрольный работа фгос лабиринт книга',
#  'социалка',
#  'почта',
#  '',
#  'счётчик моточасов поднебесный л год',
#  'директор вакансия компания магнит астрахань',
#  'репс однотонный мм',
#  'алексей остаев изба читальня литературно художественный портал',
#  'иммунный система всё документальный фильм онлайн',
#  'трахнуть раздевалка жена босс корпоратив',
#  'фото пользователь наталья красноярск год',
#  'супер фигурка серия золото ребёнок игрушка фигурка',
#  'отзыв противогрибковый средство флуконазол страница',
#  '',
#  'решение эксперт',
#  '',
#  'плюс минус учёба заочный',
#  'бюро чистота брат чистовой',
#  'сша объявить лауреат пулитцеровский премия год',
#  'аренда фрезеровочный машина бетон купить нижний новгород договорный цена компания ооо',
#  'экологический воздействие смог здоровье человек тыс результат поиск',
#  'фотосклад казань результат поиск',
#  'н',
#  'дилижанс шоу прокат аренда костюм',
#  'поздравление день ростехнадзора проза',
#  'голый жанна фриске максим фото июнь',
#  '',
#  '',
#  'капот купить владивосток цена объявл',
#  'мёртвый земля чужой рада млн результат поиск',
#  'парфюмерия отзыв покупатель',
#  'гей чат знакомство барнаул',
#  'совместный покупка омск брюки свитшот старый цена руб',
#  'десна свой исток смоленский область необычайно красивый тихий брянский новость',
#  'правильно писаться слово челюсть ударение слово челюсть',
#  'видео свет огонь видео смотреть онлайн мир',
#  'торрент порно скачать скачать курение женский туалет г порно сайтрип торрент бесплатно р',
#  'результат поиск запрос казаться размышление истинный успех интернет магазин читать город',
#  'вакансия менеджер работа торговый сеть пятигорск работа милагра',
#  'здравый биз решение ваш медицинский бизнес пример отчёт внутренний контроль качество',
#  'реквизит ооо',
#  'чамьюва бич отель турция поиск',
#  'подождать страница загружаться',
#  '',
#  'определение судебный коллегия гражданский дело вс рф кг',
#  'купон эльдорадо скидка следующий покупка февраль март',
#  'радикал фото картинка',
#  'путешествие украина посмотреть крым',
#  'читать книга работать контраст подруга любой вкус автор мазуркевич наталья онлайн сайт',
#  'купить шатура светлый кредит актобе магазин',
#  'прогноз погода северный день неделя погода северный северный свердловский область',
#  'ислам итляшев водка пить кальян курить',
#  'тест день днёвка хэтчинг запись пользователь сообщество эко мама категория образ жизнь время эко',
#  'сравнить чёрный чёрный фиолетовый',
#  'купить корпоративный подарок владимир доставка россия',
#  'укра нська л тература клас авраменко м гдз',
#  'результат поиск запрос английский фокус класс интернет магазин читать город',
#  'социальный дифференциация язык понятие литературный язык студопедия',
#  'метаданные статья студопедия',
#  'самир артист краснодар',
#  'обманка лямбда зонд грн прочий запчасть мелитополь',
#  'комплектующие батут укра н пора вняти ц придбати споживч товари маркетплейс',
#  'букет гортензия микс голубой фиолетовый',
#  'тест окружающий мир класс всё учитель тест окружающий мир класс окружающий мир задание тест викторин',
#  'шапочка лето осень зима весна макушка пяточек платок шарф шаль ребёнок',
#  '',
#  '',
#  'моторный масло л',
#  'видео',
#  'чешский русский',
#  'купить ондулин петропавловск камчатский предложение всё предложение це',
#  'сетевой контроллер нижний новгород низкий цена',
#  'шоколадница день учитель день рождение заказать ярмарка мастер открытка нижний новгород',
#  'скачать фильм лохматый папа телефон бесплатно',
#  'степень окисление атом углерод проявлять соединение неботан',
#  '',
#  'наш неуживчивый пятый раса',
#  'скачать программа здоровье фитнес андроид бесплатно',
#  '',
#  'молодой голый красотка рак показывать писю',
#  'ударница свет',
#  'пиломатериал отделка плинтус доска сухой сибирский лиственница это год упакованна полиэтиллен купить красноярск состояние новый паркет ламинат линолеум плинтус интернет аукцион',
#  'антология гарри поттер фильм смотрет',
#  'иллюстрация солнечный удар иван бунин лабиринт книга источник анит',
#  'завитинск юрист завитинск амурский область бесплатный онлайн консультация',
#  'задача оператор позвонить репетитор оператор',
#  'шаф менеджер вента агенц марини майко',
#  'проблема монитор конференция',
#  'дорога попутчик хлопоты',
#  'порно комикс инцест комикс порно комикс',
#  'мониторинг сми инвалид страница',
#  'результат поиск',
#  'навещать могила девушка конец рассказ',
#  'стрим онлайн трансляция',
#  'люстра паук деревянный патрон лофт светильник паук лампа эдисон грн св тильники ки',
#  'распоряжение мособлархитектуры рв предоставление разрешение условно разрешить вид использование земельный участок',
#  'владикавказ построить центр спортивный единоборство млн рубль',
#  'термин гараж понятие гараж определение гараж',
#  'шкаф купе цена киев шкаф кухня киев',
#  'смотреть аниме тёмный чёрный сезон бесплатно онлайн всё серия хороше',
#  'женский половой гормон расшифровка анализ норма отклонение',
#  'ботинок демисезонный купить руб интернет магазин',
#  'пресс подборщик покупка продажа цена торговый площадка агросервер ру',
#  'погода черноморовском прогноз погода черноморовском сегодня завтра неделя октябрьский район волгоградский область',
#  'александр лисиный проклинать муж свет читать онлайн',
#  'контакт друк укра',
#  'проверка трек код напрямую сайт почтовый служба система',
#  'вакансия помощник монтажник гожув велькопольски',
#  'искать девушка нижегородский область бора результат поиск знакомство найти свой половинка',
#  'субару форестер барнаул обмен вд русский нужный автомат литр полный привод',
#  'серьга танзанит танзания серебро покрытие золото карат продажа цена сумах серебряный серьга интернет магазин мир камень',
#  'простить любовь максим фадеев',
#  'квартира спальня вид море недвижимость болгария застройщик',
#  'курны раковина чаша турецкий баня хамама',
#  'раскоксовыватель поршневой кольцо антикокс мл арт купить новый',
#  'ремонт энциклопедия журнал руль',
#  'работа опыт вакансия санкт петербург',
#  'вакансия макетчик наружный реклама смоленск поиск сотрудник сайт реклама',
#  'монгольский трикотаж изделие верблюжий шерсть купить нижний тагил',
#  'запечь картошка сметана духовка картофель запечь духовка сметана',
#  'профиль',
#  'постановление правительство рф ред утверждение правило расчёт сумма страховой возмещение причинение вред',
#  'комплект брючный чёрный бордовый женский одежда',
#  'личный кабинет сервер',
#  'пекин считать школа перевоспитание концлагерь мир независимый газета',
#  'гдз история класс рабочий тетрадь симоново клок задание стр',
#  'александр соколов просто научиться жить читать книга онлайн бесплатно',
#  'презерватив удовольствие платить отзыв покупатель',
#  'бутерброд немецки острый штука шарф захе',
#  'отзыв книга суперсыщик калла блумквист сборник',
#  'вакансия грузчик санкт петербург работа компания мир инструмент полный рабочий день',
#  'адвокатский монополия',
#  'поиск тур туроператор',
#  'конфликт граница гкнб кр просить воздержаться провокационный призыв',
#  'русски недвижимость сейшелы',
#  'вид герань всё сорт название фото самобор оранжевый лососёвый роко',
#  'читать книга восстание инеевых волков си страница библиотека книга',
#  'страница найти',
#  'аренда авто услуга баксан доска бесплатный объявление услуга услугио',
#  'физика класс поурочный разработка учебник мякишева г саур ю учебник физика учебник стих сочинение школьник',
#  'упражнение повторение курс класс гдз математик класс г мерзляк б полонский м якир школа',
#  'аугсбург',
#  'поражаться либо либо падеж существительное',
#  'скачать сборка страница компьютерный форум',
#  'натали комсомольск амур фото страница',
#  'сандалия детский мальчик цвет темно синий интернет магазин',
#  'моидокументы туризм турфирма туристический агентство',
#  'татьяна луганцева целый мир против скачать литрес',
#  'оплата электроэнергия дача вопрос категория жкх',
#  'мебл замовлення мебель заказ стол ст л шкаф шафа купе кухня мебл замовлення черн вц',
#  '',
#  'погода сугояке месяц прогноз погода день красноармейский район челябинский область россия',
#  '',
#  'деревянный тумба таиланд ручной работа',
#  'рыболовный снасть новинка мир рыболовный снасть',
#  'воздушный фильтр двигатель сбор корпус продажа цена минск двигатель техника мир беседка',
#  'решение задача теоретический механика страница',
#  'цивилизация инк реферат пример образец реферат',
#  'читать манга жена президент студенческий совет глава русский онлайн',
#  'путин пошутить лишний бюрократия встреча ася новость',
#  '',
#  'отдых москва салон',
#  'эксперт алифиренко э россия отзыв эксперт алифиренко вера эдуардович',
#  '',
#  'скачать торрент г',
#  'главный страница',
#  'драйвер тыс результат поиск',
#  'медведь йога смотреть онлайн',
#  'ф алка сенпол полум н н адам н бердников продажа цена ки рослини горшков колекц ф алок м лан',
#  'тест уровень осознанность',
#  'дождливый небо гарри поттер',
#  'клонировать репозиторий урок сайт',
#  'презентация обжа семья современный общество законодательство семья',
#  'тушь ресница ива роше удлинять хотеть накладный ресница',
#  '',
#  'террариумный животное стр',
#  'холодный фарфор приготовление страна мастер',
#  'пассажирский з аммендорф серия страница модель',
#  'производство продажа изделие пластмасса ооо глобус г альметьевск',
#  'поиск запрос тумба комплект санта омега люкс подвесной',
#  'почта',
#  'работа сфера отопление вентиляция кондиционирование иркутск',
#  'жк янтарь цена сайт официальный застройщик ск мастер планировка жилой комплекс ипотека акция новостройка свердловский обл',
#  '',
#  'як обчислити м ла неправильно форми',
#  'педсовет начальный школа тематический планирование презентация урок фгос план занятие методический разработка статья рекомен',
#  'её звать шабан индийский фильм смотреть онлайн',
#  'петля трафик запчасть транспорт',
#  'скачать шалавый бесплатно',
#  '',
#  '',
#  'член жск получение имущественный вычет нужный справка выплата пай акт приём передача квартира',
#  'мотовездеход тарусь х электропакетом фара генератор акб',
#  'пресс гранулятор пгб изюм измельчитель корм ооо биоресурс украина',
#  'работа монтажник радиоэлектронный аппаратура санкт петербург вакансия монтажник радиоэлектронный аппаратура санкт петербург',
#  '',
#  'проводка задний дверь фольксваген гольф форум',
#  'песня индийский сериал появление бесплатно скачать слушать онлайн',
#  'расшифровка аббревиатура рц пмсп тыс результат поиск',
#  'основа светский этика шемшурин класс ответ задание',
#  'рубашка хлопковый длинный рукав белый мужчина недорого интернет магазин одежда арт',
#  'болеть пятка беременность боль пятка запись пользователь иришка сообщество здоровье будущий мама малыш категория боль орви грипп',
#  'скачать смотреть онлайн',
#  'прага мюнхен замок бавария',
#  'детский сад далеко дом совет адвокат юрист',
#  'раздача аккаунт танк онлайн страница форум социальный инженерия',
#  'зажигалка оригинал бик оригинал цветной упаковка штука ящик штука продажа цена донецкий область зажигалка интернет магазин майк пак',
#  'антибактериальный средство борный кислота порошок борный кислота лицо б',
#  'порно комикс перевод порно комикс порно комикс бондаж',
#  'работа негативный информация',
#  'брест беларусь',
#  'время ускорение млн результат поиск',
#  'самый зарабатывать модель',
#  'лесной поляна полянка шишкин',
#  'торрент порно новинка скачать скачать г порно сайтрип торрент бесплатно регистрация',
#  'сысоев тамара прямикова учитель жизнь',
#  'белоцвет это белоцвет',
#  '',
#  'тфомс ростовский область ростов дон инна огрн фио директор',
#  'мозаика италон оникс патинировать купить цена руб москва фото интерьер',
#  'комнатный калиненская квартира посуточно лесозаводск',
#  'трофей мастер оружелья игра',
#  'редуктор задний мост рзм сбор самоблокирующимся дифференциал вал рейсинг',
#  'экипаж смотреть онлайн хороший качество',
#  'таблетка ультрамол инструкция применение форум геленджик',
#  'фильм остров сокровище весь информация фильм',
#  'ценность общечеловеческий',
#  'лот пользователь',
#  'фауна японский море',
#  'услуга цена',
#  'инфанрикс гекса год советчица кидстафф',
#  'трахаться магазин кролик',
#  'алек сообщение',
#  'россия разработать умный часы глонасс чёрный ящик',
#  'хостинг картинка загрузить фото картинка изображение',
#  'купить наушник беспроводный зарядка чехол рассрочка руб мес салехард хоум кредит банк',
#  '',
#  'колёсный шасси википедия',
#  '',
#  'вера ивлев актриса результат поиск',
#  'молочный чудо индия',
#  'анальный дрочево пиратский принцесса',
#  'запрос куртка девочка осень найти результат интернет магазин',
#  'силикатный шлак больший энциклопедия нефть газ статья страница',
#  'финансовый отчётность ооо нефтепром зачестныйбизнес',
#  'подвал джо слокама лексингтон форум обсуждение помощь проблема запускаться решение ошибка',
#  'чужой несчастие счастие построить пользователь понравиться трогательный фото вера брежнев вера брежн',
#  'красивый порно видео скачать телефон',
#  'истребитель го поколение коммерческий миф впк сегодняшний день авиация часть конференция',
#  'купить считыватель бесконтактный карта формат хороший цена руб магазин элемент липецк',
#  'чирпы церковь смоленский икона божий мать фотография',
#  'пропасть крупный сделка предприниматель скрываться монастырь',
#  'ип ливневый эдуард львович н далее контакт телефон адрес вакансия ливневый эдуард',
#  'условие проживание пансионат аннушка',
#  '',
#  'скачать смотреть онлайн',
#  'фото видео внедорожник фотогалерея авто',
#  'работа поиск работа минск беларусь',
#  'м хтар леуберд ырт ы стереть министр болып айындалды',
#  'скачать бесплатно слушать онлайн регистрация',
#  'запрос пуховик красный найти результат интернет магазин',
#  'процесс страшный история',
#  'эротический рассказ история письмо читатель рассказ',
#  'картина номер',
#  'дикий пчела особенность характеристика жить',
#  'нежный порно молодой рыжеволосый девушка телок ласкать киска самотыком',
#  '',
#  'сколько стоить твой билет начать экономить перелёт',
#  'шкаф платяной венге комби компанит х х смотреть продажа цена киев шкаф спальня интернет магазин котяра мебель наш мебель каждый дом',
#  'компрессор спиральный',
#  'первый помощь коклюш развитие апноэ лёгкий человек строение функция лечение',
#  'дом дача м сотка снять руб носырево',
#  'край свет куллиб скачать читать онлайн отзыв',
#  'сапог женский весна осень каблук ц грн купити запорожье',
#  'столото квитанция',
#  'видео',
#  'просмотр фото',
#  'визит гнц колопроктологии страница',
#  'праймер отзыв врач отрицательный реальный развод правда цена аптека',
#  'продать айфон гб подарок фотоаппарат сума мобильный телефон ташкент',
#  'г курск телегин андрей владимирович фото тыс результат поиск',
#  'вселенная глаз телескоп хаббл фото всё космос нло',
#  '',
#  'сало деликатес мясо',
#  'смотреть аниме онлайн аниме волшебный звезда магический эми смотреть онлайн',
#  'трейнер чита чит код трейнер сохранение совет скачать бесплатно',
#  'мультанекдот бутылочка смотреть онлайн видео хороший качество видеохостинг',
#  'купон интимный контурный пластика купить скидка руб медицинский центр гинмед м водный стадион условие акция особенность купить купон москва акция сайт скидка кингкупон',
#  'дезаргент дезсредство дезкаталоге дезреестр эквивалены дезаргент',
#  'ваш посредник европа доставка товар польша',
#  'ящик инструмент автозапчасть владивосток',
#  '',
#  'продажа двухкомнатный квартира м шарикоподшипниковская ул москва ювао р н южнопортовый м дубровка база циан объявление',
#  '',
#  'поцелуй нравиться мужчина',
#  'онлайн тест фоксфорд мониторинг знание английский язык',
#  'шина диск размер колесо хюндай грандеур',
#  'маша ефросинина показать свой истинный лицо',
#  'несгораемый девушка',
#  'тыс результат поиск',
#  'региональный омбудсмен право ребёнок право человек посетить ик уфс',
#  '',
#  'вкуснятина козий молоко метка кефир домашний условие кефир домашний',
#  'мир поиск пользователь',
#  '',
#  'психология телесность теоретический практический исследование',
#  'торт свадебный титоло бейкери стрит',
#  'легковой шина ростов дон интернет маг',
#  'жилет больший размер купить недорого проверить продавец страница',
#  'женский сумка цена грн купить харьков',
#  'футболка синий россия',
#  'челябинск фигурант уголовный дело стать свалка полетаево',
#  'юбка миди складка пуговица',
#  'порно видео',
#  'критик виталий милон теория гусь порося',
#  '',
#  'групповой секс сын тупой милфы',
#  'кладовщик ооо пкф пин симферополь зп руб',
#  'порно',
#  'удалённый подключение рабочий стол',
#  'лайк',
#  'состояться аукцион продажа пакет акция пао лхк кареллеспром',
#  'домик мотив бурят голубеть страница форум строительство загородный жизнь',
#  'звезда ломбард игровой автомат',
#  'цикл хроника неночи издательство аста',
#  'ксения знакомиться',
#  '',
#  'кузов часть порог правый сторона л год',
#  'продать котёнок персидский порода пермь',
#  'перемотать коллекторный движок',
#  'шерстяной ковёр преимущество недостаток состав вид влиять цена ковровый шерсть',
#  'найти справочный служба хабаровск узнать адрес телефон',
#  'песня',
#  '',
#  'фотоальбом анна овен ревда',
#  'газовый плита ширина смотреть купить газовый плита ширина смотреть цена отзыв продажа газовый плита интернет магазин ситилинк геленджик',
#  'якори самовытаскивания уаз патриот хантер буханка купить интернет магазин тюнинг уаз бесплатный доставка москва',
#  '',
#  'подглядеть парочка парковка порно видео онлайн',
#  'площадь квартира кадастровый номер существовать способ получить данна',
#  'влезть фонетический звуко буквенный разбор слово',
#  'грязный минуть озаботить сосалки',
#  'роман год россия санкт петербург познакомиться девушка возраст год сеть знакомство мамба',
#  '',
#  'зелёный чай молоко похудение',
#  'секс инцест порно анал трах член измена жёсткий видео',
#  'мода сообщество империал страница',
#  'парень бомбить куннилингус распутный мажорке',
#  'отчётный концерт школа танец менада гродно',
#  'скачать песня бесплатно слушать онлайн',
#  'елена год латвия рига познакомиться парень возраст год сеть знакомство мамба',
#  '',
#  'мир поиск пользователь',
#  'весёлый старт пришкольный лагер берёзка июнь шахтёрский общеобразовательный школа',
#  'откидывать морфологический разбор слово часть речь',
#  'горный воздух парапланерный клуб сахалин бизнес справочник',
#  'официальный сайт школа г златоуст школа город каталог сайт официальный сайт маоу сош г златоуст',
#  '',
#  'видео',
#  '',
#  'чтение манга клинок рассекать демон глава',
#  'домик питомец',
#  'английский язык тереть минасовой г др класс',
#  'работа поиск работа минск беларусь',
#  'приговор апрель г дело судакт ру',
#  'кг темно серый комплект утяжелитель купить минск',
#  'видео онлайн',
#  'плохой девочка эротический бельё красивый девушка',
#  'поступление университет часть подготовка тест',
#  'арована американский белый серебряный арована содержание питание размножить',
#  '',
#  'полезный совет тыс результат поиск',
#  'красавица мёртвый локон златой скачать читать онлайн полно бесплатный книга алан брэдли',
#  'рабочий программа география класс час неделя',
#  'мир',
#  'супермаркет кипр протарас деревня адрес телефон режим работа сайт магазин',
#  'журнал бухгалтерия делопроизводство кадровый работа стр',
#  'халат рабочий каталог модель санкт петербург страница',
#  'восстановление пароль',
#  '',
#  'удаление гнилой корень зуб цена фото',
#  'купить макетный нож скрапбукинга санкт петербург низкий цена макетный нож скрапбукинга',
#  'троить двигатель чистка карбов синхронизация сузук',
#  'конический хвостовик это конический хвостовик',
#  'фото альбом портфолио оформление свадебный зал марина чикалиди',
#  'набор нож томат блистер смотреть шт купить доставка цена р описание отзыв интернет магазин утконос онлай',
#  'связь молодёжный субкультура адаптация ребёнок мигрант новый социокультурный',
#  'ремонт стационарный телефон сочи справочник организация',
#  'барахолка услуга большой воронежский форум',
#  '',
#  'администрация муниципальный образование вистинское сельский поселение утверждение кодекс этика служебный поведение муниципальный служащий',
#  'саша сигуев сев николаев фильм осторожно ребёнок фотография',
#  'скачать торрент бесплатно',
#  'крутой',
#  'таиланд пхукет отзыв отель цена фото номер забронировать отель онлайн',
#  'кукла младенец пупс близняшка коляска купить рассрочка минск низкий цена',
#  'любвеобильный девушка друг',
#  'запешите слово распредиляя группа орфограмма корень ленивый честный',
#  '',
#  'свадебный набор свадебный бижутерия оптом хороший цена компания бижутерия оптом одесса украина страница',
#  'снять комнатный квартира посредник новороссийск объявление аренда однокомнатный квартира собственник длительный',
#  'несладкий начинка блин хороший рецепт фото сегодня',
#  'выбирать оптимальный видеокарта процессор страница',
#  'спам почта',
#  'читать манга расколоть битва синева небо глава русский онлайн',
#  '',
#  'зона особый скачать бесплатно зона особый',
#  'больший гей отдохнуть сеновал отменно потрахались втроём порно онлайн хороший качество',
#  'субтитр страница хентай онлайн смотреть бесплатно',
#  'толстовка толстовка воротник тип рубашка принтом сезон осень зима женский толстовка свитшоты',
#  '',
#  'клубневой бегония любимый сорт страница форум цветовод фрау флора',
#  'страница',
#  'застукать дочь трахаться кухонный стол',
#  'измельчать юбилей донецк приехать сбить лётчик российский эстрада',
#  'ярославль сгореть дзержинский рынок сентябрь г остаться',
#  'фестал др цена москва рубль',
#  'софья апфельбаум биография карьера семья фото',
#  'антоним слово духовность',
#  'владимир тучковский вильнюс литва год мир',
#  'шрус внеш',
#  'миниборд пенни минь борд скейтборд спортдоставке спортдоставка белгород',
#  'покраснеть десна бэбиблог',
#  'декоративный карниз штора витязь однорядный мм золото патина длина смотреть широкий выбор товар магазин сравнить цена',
#  'настройка лаитб з',
#  '',
#  '',
#  'летний итальянка родить ребёнок новый известие',
#  'штукатурка потолок цена м москва',
#  '',
#  'куркума молотый добавка полезный лечебный свойство специя применение кулинария купить москва цена отзыв полезный свойство',
#  'поиск названый брат',
#  'отчаянный домохозяйка серия муж свинья й сезон мегафон тв',
#  'мир',
#  'суперскидки',
#  '',
#  'облако милоты',
#  'дарынды балалар арнал ан абай атында ы лицей мектеб абай атында ы лицей мектеб ма ала зд аз ы',
#  'поиск запрос смарт браслет',
#  'скачать обои земля мир карбон раздел текстура разрешение',
#  '',
#  'писать требование письменно объяснительный ь млн результат поиск',
#  'татьяна назаров биография фото фильм личный жизнь новость сми',
#  '',
#  'комплекс утренний гимнастика весёлый платочек первый младший группа воспитатель детский сад школьный учитель педагог маам ру',
#  'постановление февраль г дело судакт ру',
#  'всяко разный брызговик л год',
#  'крепкий лысый трахарь жарить молодой шалавый больший пенис',
#  'салат копчёный колбаса огурец простой рецепт фото',
#  'юрий сёмин пусть уткин продолжать оригинальничать случайный победа новость еврокубков футбол спорт',
#  'рассекать волна',
#  '',
#  'мойка мотор снятие передний бампер крыло подкрыльев л год',
#  '',
#  'твой имя апрель группа пацанок скачать бесплатно слушать онлайн',
#  'шутка погода погода дождь снег жара жарко',
#  'страница',
#  'фото альбом свадебный ванда боголепов',
#  'мода страница',
#  '',
#  '',
#  'принтер этикетка сервис ккт',
#  'деревянный кровать массив ясень дуб предоплата грн мебель спальня белый церковь',
#  'секс ролик качество смотреть онлайн',
#  'анкетка ру личный кабинет',
#  '',
#  'скачать музыка бесплатно',
#  'порно модель популярный порно видео актриса мир адалта',
#  'решение январь г дело судакт ру',
#  'срочно неделя очень низкий хгч дикий',
#  'камаз новый заводский седельный тягач набережный челны',
#  'режим график работа страховой компания ресо гарантия волгодонск',
#  'сервис международный перевод',
#  'модель принтер принтер',
#  'главный инженер газовый труба замуровать опор строиться здание никакой угроза',
#  'читать книга звенеть бубна страница библиотека книга',
#  'альбом оксана дупик скорпион чита',
#  'кредит залог недвижимость тинькофф помощь',
#  'электромясорубка характеристика технический описание интернет магазин м видео ульяновск ульяновск',
#  'комбинезон пижама молния лёгкий верблюд лкм бк верба',
#  'поиск продукт хонда дио',
#  'презентация тема исследователь внеурочный деятельность руководитель кр',
#  'игра престол сезон серия смотреть онлайн реклама',
#  'тележка инструментальный откидной верхом двухстворчатый шкаф боковой перфорация х х мм полка х х мм шкаф х х мм цена руб купить минск',
#  'скачать самп последний версия результат поиск',
#  'просмотр резюме',
#  '',
#  'мортал комбат порно поиск',
#  'бритва смена кассета купить сеть магазин лента',
#  'заказ успешно добавить спкубани совместный покупка краснодар краснодарский край крым',
#  'туника вуаль ажурный завязка продажа цена киев пляжный одежда парео тд',
#  'кормление коза кукурузный силос фермер ру главный фермерский портал всё бизнес сельский хозяйство форум фермер',
#  'продажа участок московский область база циан объявление',
#  'прдам газель категория газ газель бортовый грузовик симферополь',
#  'далее билет сентябрь ноглики южный сахалинск выбор поезд',
#  '',
#  'блок преобразователь импульсный бпи иссан охра далее',
#  'ремонт любой сложность монтаж окно откос ключ троительные услуга запорожье',
#  '',
#  'интернет провайдер красково люберецкий район московский область подключить интернет адрес дом красково люберецкий район мо',
#  'сапог женщина россия',
#  'вакансия операционный директор симферополь продукт ермолино сайт электро',
#  'конспект урок русский язык тема комплексный работа текст кла',
#  '',
#  'биксеноновые линза ангельский глазок акционной цена',
#  'знакомство найти свой половинка ольга россия омск познакомиться парень возраст год',
#  'миньон банан слушать скачать',
#  '',
#  'звезда высокий кухня глобальный еврейский онлайн центр',
#  '',
#  '',
#  'запчасть легковой авто грузовик спецтехник красноярск',
#  'вакансия работа промоутер раздача листовка сочи поиск работа городработ ру',
#  '',
#  'лента новость',
#  'город атырау тоо конус строй млн результат поиск',
#  'секс скачать бесплатно голый японский девушка иметь большой удовольствие группа озаботить парень время открытый воздух',
#  'девушка красный платье лес аватар яркий девушка платье фотография ава',
#  'написать музыка маэстро обсуждение российский сервис',
#  '',
#  'ип князев дмитрий александрович инна огрн',
#  'майстер клас кв ти з фольга грудня ньковецький бдют',
#  'нота родион щедрин играть балалайка нота фортепиано',
#  'извращенец играть больший сиська связанный дамочка',
#  'открытка вытынанки новый год свой рука',
#  'ленинградский метрополитен',
#  'приказ генпрокуратура рф обеспечение участие прокурор гражданский судопроизводство',
#  'подробность убийство денис тен рассказать мать',
#  'отзыв обойный клей весь вид виниловый обои',
#  'автосканер мультимарочный сканматик',
#  'фильм скорость год выпуск дата выход рейтинг продолжительность похожий фильм',
#  'гвинея природа авторский платформа',
#  '',
#  'подготовить подросток взрослый жизнь папамамам миф',
#  'ауди тыс результат поиск',
#  'крещение русь урок учебный пособие основа православный культура учащи',
#  'брюнетка порно скачать бесплатно отличный качество',
#  'люся кретова видео',
#  'сказочный русалка предлагать погрузиться пучина страсть картинка',
#  '',
#  'комнатный квартира посуточно бишкек логвиненко улица объявление суточный ру',
#  '',
#  'обзор матч уралмаш цска федерация баскетбол свердловский область',
#  'подруга ебутся мужик сквиртуют лить сперма рот рот',
#  'презентация тема криминалистический методика скачать бесплатно',
#  'ультрамодный свадебный причёска',
#  'список использовать литература формирование устный речь ребёнок нарушение слух',
#  'читать манга день глава русский онлайн',
#  'купить москва рольф центр расположить центр москва минута ттк рядом москва сити литр бензин левый руль бу',
#  'венеролог прайс лист город слюдянка расценка цена прейскурант',
#  'свитшот мужской кофта весенний осенний цена грн купить киев',
#  'компания фильм вселенная',
#  'порно страница',
#  'рассчитать оптический сила система рассеивать собирать линза иметь фокусный расстояние смотреть смотреть',
#  'знать новый глава администрация президент антон вайно',
#  'минусовки зиверт юлия парус',
#  ...]

# %% [markdown]
# # CountVectoriser

# %%
vectorizer = CountVectorizer(lowercase=True, stop_words=stop_words)

X_train_vectorized = vectorizer.fit_transform(X_train)

X_train_vectorized
# Out:
# <135309x189711 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1120352 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## LogisticRegression

# %%
model = LogisticRegression()

# %%
# %time

model.fit(X_train_vectorized, y_train)

y_pred = model.predict(X_train_vectorized)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.29 µs

# %%
f1_score(y_train, y_pred)
# Out:
# 0.9746839317966144

# %%
X_test_vectorized = vectorizer.transform(X_test)

test_df["target"] = model.predict(X_test_vectorized).astype(bool)

test_df[["id", "target"]].to_csv("log_reg.csv", index=False)

# !cat ml_baseline.csv | head
# Out:
# id,target
# 135309,False
# 135310,False
# 135311,False
# 135312,True
# 135313,False
# 135314,False
# 135315,False
# 135316,False
# 135317,False
# cat: write error: Broken pipe

# %% [markdown]
# ## SGDClassifier

# %%
model = SGDClassifier()

# %%
# %time

model.fit(X_train_vectorized, y_train)

y_pred = model.predict(X_train_vectorized)
# Out:
# CPU times: user 1 µs, sys: 1e+03 ns, total: 2 µs
# Wall time: 5.72 µs

# %%
f1_score(y_train, y_pred)
# Out:
# 0.957971733201091

# %%
X_test_vectorized = vectorizer.transform(X_test)

test_df["target"] = model.predict(X_test_vectorized).astype(bool)

test_df[["id", "target"]].to_csv("SGD.csv", index=False)

# !cat ml_baseline.csv | head
# Out:
# id,target
# 135309,False
# 135310,False
# 135311,False
# 135312,True
# 135313,False
# 135314,False
# 135315,False
# 135316,False
# 135317,False
# cat: write error: Broken pipe

# %% [markdown]
# ## ComplementNB

# %%
model = ComplementNB()

# %%
# %time

model.fit(X_train_vectorized, y_train)

y_pred = model.predict(X_train_vectorized)
# Out:
# CPU times: user 1e+03 ns, sys: 1e+03 ns, total: 2 µs
# Wall time: 5.25 µs

# %%
f1_score(y_train, y_pred)
# Out:
# 0.8324219348903767

# %% [markdown]
# ## MultinomialNB

# %%
model = MultinomialNB()

# %%
# %time

model.fit(X_train_vectorized, y_train)

y_pred = model.predict(X_train_vectorized)
# Out:
# CPU times: user 1e+03 ns, sys: 0 ns, total: 1e+03 ns
# Wall time: 2.38 µs

# %%
f1_score(y_train, y_pred)
# Out:
# 0.9097784676167632

# %% [markdown]
# # TfidfVectorizer

# %%
# tfidf_vectorizer = TfidfVectorizer(lowercase=True, ngram_range=(2, 4), analyzer='char', min_df=5, max_df=0.8)

# X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
# X_test_tfidf = tfidf_vectorizer.fit_transform(X_test)

# %%
def parse_url(url):
    return url[:url.rfind('.')].replace('www.', '')

# %%
X_train_url = (train_df["url"].apply(lambda x: parse_url(x)) + " " + train_df["title"]).values
X_test_url = (test_df["url"].apply(lambda x: parse_url(x)) + " " + test_df["title"]).values

X_train_url_cleared = train_df["url"].apply(lambda x: parse_url(x)).values + " " + X_train_cleared
X_test_url_cleared = test_df["url"].apply(lambda x: parse_url(x)).values + " " + X_test_cleared

# %%
X_train_url_cleared
# Out:
# array(['m.kpэкс министр экономика молдова глава мидэи цель который сделать республика проситель донор избегать долгий нахождение н',
#        'kpпесня стать известный многий телезритель благодаря сериал диверсант',
#        'fanserialsбанши сезон серия бремя красота смотреть онлайн', ...,
#        'topclassiccarsforsale',
#        'wowcreamкупить сыворотка питательный мл москва',
#        'ubuтехнический спирт канистра флакон купить москва'], dtype=object)

# %%
X_test_url_cleared
# Out:
# array(['kommersant шестой кассационный суд самара начать работа разный здание фото коммерсантъ',
#        'urexpert индексация алименты случай производиться каков порядок правило процедура',
#        'imperimeha женщина империя мех', ...,
#        'xn----8sbnqchpeeeth администрация лесной район тверской область годовщина снятие блокада',
#        'www-sunhome-ru.cdn.ampproject сонник изменение сознание сниться изменение сознание видеть сон сонник дом солнце',
#        'virtual-hockey строительство база команда гранд рапидс гриффинс гранд рапидс сша'],
#       dtype=object)

# %% [markdown]
# ## LogisticRegression

# %%
char_tfidf_log_reg = Pipeline([
    (
        'vectorizer',
        TfidfVectorizer(
            lowercase=True, ngram_range=(2, 4), analyzer='char',
            min_df=5, max_df=0.8
        )
    ),
    ('clf', LogisticRegression(class_weight='balanced', random_state=SEED))
])

# %%
# %time

char_tfidf_log_reg.fit(X_train_url_cleared, y_train)

y_pred = char_tfidf_log_reg.predict(X_train_url_cleared)
# Out:
# CPU times: user 1e+03 ns, sys: 1 µs, total: 2 µs
# Wall time: 3.81 µs
# /home/ilya/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
f1_score(y_train, y_pred)
# Out:
# 0.9602154273801251

# %%
test_df["target"] = char_tfidf_log_reg.predict(X_test_url).astype(bool)

test_df[["id", "target"]].to_csv("log_reg_tfidf.csv", index=False)

# !cat ml_baseline.csv | head
# Out:
# id,target
# 135309,False
# 135310,False
# 135311,False
# 135312,True
# 135313,False
# 135314,False
# 135315,False
# 135316,False
# 135317,False
# cat: write error: Broken pipe

# %% [markdown]
# ## SGDClassifier

# %%
char_tfidf_sgd = Pipeline([
    (
        'vectorizer',
        TfidfVectorizer(
            lowercase=True, ngram_range=(2, 4), analyzer='char',
            min_df=5, max_df=0.8
        )
    ),
    ('clf', SGDClassifier(random_state=SEED, loss='log', class_weight='balanced'))
])

# %%
# %time

char_tfidf_sgd.fit(X_train_url, y_train)

y_pred = char_tfidf_sgd.predict(X_train_url)
# Out:
# CPU times: user 1e+03 ns, sys: 1e+03 ns, total: 2 µs
# Wall time: 4.05 µs

# %%
f1_score(y_train, y_pred)
# Out:
# 0.9602877355686344

# %%
test_df["target"] = char_tfidf_sgd.predict(X_test_url).astype(bool)

test_df[["id", "target"]].to_csv("SGD_tfidf.csv", index=False)

# !cat ml_baseline.csv | head
# Out:
# id,target
# 135309,False
# 135310,False
# 135311,False
# 135312,True
# 135313,False
# 135314,False
# 135315,False
# 135316,False
# 135317,False
# cat: write error: Broken pipe
