# %%
import pandas as pd

# %%
df = pd.read_csv("./data/Train.csv")

# %%
df
# Out:
#           id    date  street_id  build_tech  floor  area  rooms  balcon  \
# 0          0  2011-1        560         NaN      2    59      3       0
# 1          1  2011-1        667         NaN     10    50      2       1
# 2          2  2011-1         90         0.0      1    48      2       0
# 3          3  2011-1         94         1.0      3    62      3       1
# 4          4  2011-1        232         0.0      3    60      3       0
# ...      ...     ...        ...         ...    ...   ...    ...     ...
# 99995  99995  2012-3        401         0.0      5    30      1       0
# 99996  99996  2012-3         59         0.0      4    34      1       0
# 99997  99997  2012-3        253         NaN      3    52      2       0
# 99998  99998  2012-3        305         1.0      3   181      5       1
# 99999  99999  2012-3        482         0.0      7    57      2       0
#
#        metro_dist  g_lift  ...  kw5  kw6  kw7  kw8  kw9  kw10  kw11  kw12  \
# ...
